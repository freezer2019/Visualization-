# %% [markdown]
# ### COVID-19 on ventilator prediction model based on Covid cases and hospitalisation

# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC  
from sklearn.linear_model import LinearRegression 
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import seaborn as sns
import matplotlib.pyplot as plt
import datetime as dt

# %%
# Get the curent date/time
today = pd.to_datetime('today')
today
# Out:
# Timestamp('2020-12-11 21:47:28.220853')

# %%
# Downloads the lates data availlable and saves it.
# Run this step dayly to update the data.

# df_Covid_data = pd.read_csv('https://covidtracking.com/data/download/national-history.csv')
# df_Covid_data.to_csv('National_Covid_Data_'+today.strftime("%Y-%m-%d")+'.csv')

# %%
# Loads the last saved data. Make sure the data is up to date by running the cell above. 
df_Covid_data = pd.read_csv('National_Covid_Data_'+today.strftime("%Y-%m-%d")+'.csv')
df_Covid_data
# Out:
#      Unnamed: 0        date     death  deathIncrease  inIcuCumulative  \
# 0             0  2020-12-11  287058.0           2749          33237.0
# 1             1  2020-12-10  284309.0           3115          32919.0
# 2             2  2020-12-09  281194.0           3206          32720.0
# 3             3  2020-12-08  277988.0           2661          32406.0
# 4             4  2020-12-07  275327.0           1297          32120.0
# ..          ...         ...       ...            ...              ...
# 320         320  2020-01-26       NaN              0              NaN
# 321         321  2020-01-25       NaN              0              NaN
# 322         322  2020-01-24       NaN              0              NaN
# 323         323  2020-01-23       NaN              0              NaN
# 324         324  2020-01-22       NaN              0              NaN
#
#      inIcuCurrently  hospitalizedIncrease  hospitalizedCurrently  \
# 0           21010.0                  5444               108108.0
# 1           21023.0                  4335               107258.0
# 2           20906.0                  5424               106705.0
# 3           20483.0                  4309               104590.0
# 4           20098.0                  3614               102148.0
# ..              ...                   ...                    ...
# 320             NaN                     0                    NaN
# 321             NaN                     0                    NaN
# 322             NaN                     0                    NaN
# 323             NaN                     0                    NaN
# 324             NaN                     0                    NaN
#
#      hospitalizedCumulative   negative  negativeIncrease  \
# 0                  608998.0  168637806           1449905
# 1                  603554.0  167187901           1339749
# 2                  599219.0  165848152           1276606
# 3                  593795.0  164571546           1192820
# 4                  589486.0  163378726           1386381
# ..                      ...        ...               ...
# 320                     NaN          0                 0
# 321                     NaN          0                 0
# 322                     NaN          0                 0
# 323                     NaN          0                 0
# 324                     NaN          0                 0
#
#      onVentilatorCumulative  onVentilatorCurrently  positive  \
# 0                    3424.0                 7489.0  15592946
# 1                    3394.0                 7442.0  15360841
# 2                    3376.0                 7624.0  15145172
# 3                    3359.0                 7245.0  14934152
# 4                    3328.0                 7073.0  14718817
# ..                      ...                    ...       ...
# 320                     NaN                    NaN         0
# 321                     NaN                    NaN         0
# 322                     NaN                    NaN         0
# 323                     NaN                    NaN         0
# 324                     NaN                    NaN         0
#
#      positiveIncrease  recovered  states  totalTestResults  \
# 0              232105  6135314.0      56         215110717
# 1              215669  5985047.0      56         213015816
# 2              211020  5891885.0      56         211061130
# 3              215335  5788509.0      56         209239063
# 4              180219  5714557.0      56         207610631
# ..                ...        ...     ...               ...
# 320                 0        NaN       2                 2
# 321                 0        NaN       2                 2
# 322                 0        NaN       2                 2
# 323                 0        NaN       2                 2
# 324                 0        NaN       2                 1
#
#      totalTestResultsIncrease
# 0                     2094901
# 1                     1954686
# 2                     1822067
# 3                     1628432
# 4                     1772911
# ..                        ...
# 320                         0
# 321                         0
# 322                         0
# 323                         1
# 324                         0
#
# [325 rows x 19 columns]

# %%
# Check for shape, null values and data types of the data
print("Size/Shape of the dataset",df_Covid_data.shape)
print("Checking for null values:\n",df_Covid_data.isnull().sum())
print("Checking Data-type:",df_Covid_data.dtypes)
# Out:
# Size/Shape of the dataset (325, 19)
# Checking for null values:
#  Unnamed: 0                   0
# date                         0
# death                       19
# deathIncrease                0
# inIcuCumulative             63
# inIcuCurrently              64
# hospitalizedIncrease         0
# hospitalizedCurrently       55
# hospitalizedCumulative      42
# negative                     0
# negativeIncrease             0
# onVentilatorCumulative      70
# onVentilatorCurrently       63
# positive                     0
# positiveIncrease             0
# recovered                   63
# states                       0
# totalTestResults             0
# totalTestResultsIncrease     0
# dtype: int64
# Checking Data-type: Unnamed: 0                    int64
# date                         object
# death                       float64
# deathIncrease                 int64
# inIcuCumulative             float64
# inIcuCurrently              float64
# hospitalizedIncrease          int64
# hospitalizedCurrently       float64
# hospitalizedCumulative      float64
# negative                      int64
# negativeIncrease              int64
# onVentilatorCumulative      float64
# onVentilatorCurrently       float64
# positive                      int64
# positiveIncrease              int64
# recovered                   float64
# states                        int64
# totalTestResults              int64
# totalTestResultsIncrease      int64
# dtype: object

# %%
# Print the column names
df_Covid_data.columns
# Out:
# Index(['Unnamed: 0', 'date', 'death', 'deathIncrease', 'inIcuCumulative',
#        'inIcuCurrently', 'hospitalizedIncrease', 'hospitalizedCurrently',
#        'hospitalizedCumulative', 'negative', 'negativeIncrease',
#        'onVentilatorCumulative', 'onVentilatorCurrently', 'positive',
#        'positiveIncrease', 'recovered', 'states', 'totalTestResults',
#        'totalTestResultsIncrease'],
#       dtype='object')

# %%
#Drop columns that are not needed for the model
df_Covid_data.drop(['Unnamed: 0','death',\
       'deathIncrease','onVentilatorCumulative','states'],1,inplace = True)

# %%
df_Covid_data.columns
# Out:
# Index(['date', 'inIcuCumulative', 'inIcuCurrently', 'hospitalizedIncrease',
#        'hospitalizedCurrently', 'hospitalizedCumulative', 'negative',
#        'negativeIncrease', 'onVentilatorCurrently', 'positive',
#        'positiveIncrease', 'recovered', 'totalTestResults',
#        'totalTestResultsIncrease'],
#       dtype='object')

# %%
df_Covid_data
# Out:
#            date  inIcuCumulative  inIcuCurrently  hospitalizedIncrease  \
# 0    2020-12-11          33237.0         21010.0                  5444
# 1    2020-12-10          32919.0         21023.0                  4335
# 2    2020-12-09          32720.0         20906.0                  5424
# 3    2020-12-08          32406.0         20483.0                  4309
# 4    2020-12-07          32120.0         20098.0                  3614
# ..          ...              ...             ...                   ...
# 320  2020-01-26              NaN             NaN                     0
# 321  2020-01-25              NaN             NaN                     0
# 322  2020-01-24              NaN             NaN                     0
# 323  2020-01-23              NaN             NaN                     0
# 324  2020-01-22              NaN             NaN                     0
#
#      hospitalizedCurrently  hospitalizedCumulative   negative  \
# 0                 108108.0                608998.0  168637806
# 1                 107258.0                603554.0  167187901
# 2                 106705.0                599219.0  165848152
# 3                 104590.0                593795.0  164571546
# 4                 102148.0                589486.0  163378726
# ..                     ...                     ...        ...
# 320                    NaN                     NaN          0
# 321                    NaN                     NaN          0
# 322                    NaN                     NaN          0
# 323                    NaN                     NaN          0
# 324                    NaN                     NaN          0
#
#      negativeIncrease  onVentilatorCurrently  positive  positiveIncrease  \
# 0             1449905                 7489.0  15592946            232105
# 1             1339749                 7442.0  15360841            215669
# 2             1276606                 7624.0  15145172            211020
# 3             1192820                 7245.0  14934152            215335
# 4             1386381                 7073.0  14718817            180219
# ..                ...                    ...       ...               ...
# 320                 0                    NaN         0                 0
# 321                 0                    NaN         0                 0
# 322                 0                    NaN         0                 0
# 323                 0                    NaN         0                 0
# 324                 0                    NaN         0                 0
#
#      recovered  totalTestResults  totalTestResultsIncrease
# 0    6135314.0         215110717                   2094901
# 1    5985047.0         213015816                   1954686
# 2    5891885.0         211061130                   1822067
# 3    5788509.0         209239063                   1628432
# 4    5714557.0         207610631                   1772911
# ..         ...               ...                       ...
# 320        NaN                 2                         0
# 321        NaN                 2                         0
# 322        NaN                 2                         0
# 323        NaN                 2                         1
# 324        NaN                 1                         0
#
# [325 rows x 14 columns]

# %%
# Drop the null rows and sort the data by date
df_Covid_data = df_Covid_data.dropna()
df_Covid_data = df_Covid_data.sort_values(by = "date", ascending = True)
df_Covid_data
# Out:
#            date  inIcuCumulative  inIcuCurrently  hospitalizedIncrease  \
# 260  2020-03-26             91.0          1299.0                  2478
# 259  2020-03-27            124.0          1792.0                  2572
# 258  2020-03-28            140.0          2174.0                  2409
# 257  2020-03-29            156.0          2456.0                  2794
# 256  2020-03-30            187.0          3087.0                  2472
# ..          ...              ...             ...                   ...
# 4    2020-12-07          32120.0         20098.0                  3614
# 3    2020-12-08          32406.0         20483.0                  4309
# 2    2020-12-09          32720.0         20906.0                  5424
# 1    2020-12-10          32919.0         21023.0                  4335
# 0    2020-12-11          33237.0         21010.0                  5444
#
#      hospitalizedCurrently  hospitalizedCumulative   negative  \
# 260                 7805.0                  9551.0     482148
# 259                10978.0                 12123.0     559423
# 258                12409.0                 14532.0     657185
# 257                14055.0                 17326.0     722597
# 256                15917.0                 19798.0     818231
# ..                     ...                     ...        ...
# 4                 102148.0                589486.0  163378726
# 3                 104590.0                593795.0  164571546
# 2                 106705.0                599219.0  165848152
# 1                 107258.0                603554.0  167187901
# 0                 108108.0                608998.0  168637806
#
#      negativeIncrease  onVentilatorCurrently  positive  positiveIncrease  \
# 260             86516                  258.0     92976             17734
# 259             77275                  324.0    112220             19244
# 258             97762                  390.0    131826             19606
# 257             65412                  439.0    151270             19444
# 256             95634                  451.0    172740             21470
# ..                ...                    ...       ...               ...
# 4             1386381                 7073.0  14718817            180219
# 3             1192820                 7245.0  14934152            215335
# 2             1276606                 7624.0  15145172            211020
# 1             1339749                 7442.0  15360841            215669
# 0             1449905                 7489.0  15592946            232105
#
#      recovered  totalTestResults  totalTestResultsIncrease
# 260       97.0            643502                    108279
# 259     2418.0            739132                     95630
# 258     3145.0            840610                    101478
# 257     4076.0            919937                     79327
# 256     4560.0           1034163                    114226
# ..         ...               ...                       ...
# 4    5714557.0         207610631                   1772911
# 3    5788509.0         209239063                   1628432
# 2    5891885.0         211061130                   1822067
# 1    5985047.0         213015816                   1954686
# 0    6135314.0         215110717                   2094901
#
# [261 rows x 14 columns]

# %%
# Set the date as index
df_Covid_data.set_index('date', inplace =True)
df_Covid_data
# Out:
#             inIcuCumulative  inIcuCurrently  hospitalizedIncrease  \
# date
# 2020-03-26             91.0          1299.0                  2478
# 2020-03-27            124.0          1792.0                  2572
# 2020-03-28            140.0          2174.0                  2409
# 2020-03-29            156.0          2456.0                  2794
# 2020-03-30            187.0          3087.0                  2472
# ...                     ...             ...                   ...
# 2020-12-07          32120.0         20098.0                  3614
# 2020-12-08          32406.0         20483.0                  4309
# 2020-12-09          32720.0         20906.0                  5424
# 2020-12-10          32919.0         21023.0                  4335
# 2020-12-11          33237.0         21010.0                  5444
#
#             hospitalizedCurrently  hospitalizedCumulative   negative  \
# date
# 2020-03-26                 7805.0                  9551.0     482148
# 2020-03-27                10978.0                 12123.0     559423
# 2020-03-28                12409.0                 14532.0     657185
# 2020-03-29                14055.0                 17326.0     722597
# 2020-03-30                15917.0                 19798.0     818231
# ...                           ...                     ...        ...
# 2020-12-07               102148.0                589486.0  163378726
# 2020-12-08               104590.0                593795.0  164571546
# 2020-12-09               106705.0                599219.0  165848152
# 2020-12-10               107258.0                603554.0  167187901
# 2020-12-11               108108.0                608998.0  168637806
#
#             negativeIncrease  onVentilatorCurrently  positive  \
# date
# 2020-03-26             86516                  258.0     92976
# 2020-03-27             77275                  324.0    112220
# 2020-03-28             97762                  390.0    131826
# 2020-03-29             65412                  439.0    151270
# 2020-03-30             95634                  451.0    172740
# ...                      ...                    ...       ...
# 2020-12-07           1386381                 7073.0  14718817
# 2020-12-08           1192820                 7245.0  14934152
# 2020-12-09           1276606                 7624.0  15145172
# 2020-12-10           1339749                 7442.0  15360841
# 2020-12-11           1449905                 7489.0  15592946
#
#             positiveIncrease  recovered  totalTestResults  \
# date
# 2020-03-26             17734       97.0            643502
# 2020-03-27             19244     2418.0            739132
# 2020-03-28             19606     3145.0            840610
# 2020-03-29             19444     4076.0            919937
# 2020-03-30             21470     4560.0           1034163
# ...                      ...        ...               ...
# 2020-12-07            180219  5714557.0         207610631
# 2020-12-08            215335  5788509.0         209239063
# 2020-12-09            211020  5891885.0         211061130
# 2020-12-10            215669  5985047.0         213015816
# 2020-12-11            232105  6135314.0         215110717
#
#             totalTestResultsIncrease
# date
# 2020-03-26                    108279
# 2020-03-27                     95630
# 2020-03-28                    101478
# 2020-03-29                     79327
# 2020-03-30                    114226
# ...                              ...
# 2020-12-07                   1772911
# 2020-12-08                   1628432
# 2020-12-09                   1822067
# 2020-12-10                   1954686
# 2020-12-11                   2094901
#
# [261 rows x 13 columns]

# %%
# Specified data columns to be used in the model 
X = df_Covid_data[['hospitalizedIncrease','hospitalizedCurrently','positive',\
             'positiveIncrease','recovered']]
y = df_Covid_data['onVentilatorCurrently'].values.reshape(-1,1)
y
# Out:
# array([[ 258.],
#        [ 324.],
#        [ 390.],
#        [ 439.],
#        [ 451.],
#        [ 507.],
#        [ 561.],
#        [ 574.],
#        [ 623.],
#        [ 656.],
#        [ 652.],
#        [2961.],
#        [4076.],
#        [4131.],
#        [5794.],
#        [5937.],
#        [5978.],
#        [5968.],
#        [6168.],
#        [5975.],
#        [6032.],
#        [5940.],
#        [6096.],
#        [5729.],
#        [5603.],
#        [5567.],
#        [5514.],
#        [5474.],
#        [5464.],
#        [5187.],
#        [5266.],
#        [5121.],
#        [4867.],
#        [4760.],
#        [4796.],
#        [4712.],
#        [4707.],
#        [4845.],
#        [4761.],
#        [4848.],
#        [4818.],
#        [4753.],
#        [7070.],
#        [6788.],
#        [6551.],
#        [6395.],
#        [6350.],
#        [6352.],
#        [6156.],
#        [5940.],
#        [5746.],
#        [5529.],
#        [5467.],
#        [5257.],
#        [5032.],
#        [4911.],
#        [4868.],
#        [4716.],
#        [4620.],
#        [4383.],
#        [4237.],
#        [4215.],
#        [4222.],
#        [4080.],
#        [4032.],
#        [4004.],
#        [3669.],
#        [3950.],
#        [3852.],
#        [3749.],
#        [3665.],
#        [3523.],
#        [3476.],
#        [3298.],
#        [3240.],
#        [3090.],
#        [3020.],
#        [2886.],
#        [2734.],
#        [2726.],
#        [2716.],
#        [2640.],
#        [2594.],
#        [2588.],
#        [2520.],
#        [2434.],
#        [2380.],
#        [2321.],
#        [2299.],
#        [2293.],
#        [2248.],
#        [2214.],
#        [2075.],
#        [2159.],
#        [2077.],
#        [2011.],
#        [2044.],
#        [2098.],
#        [2105.],
#        [2049.],
#        [1982.],
#        [2080.],
#        [2105.],
#        [2098.],
#        [2172.],
#        [2127.],
#        [2197.],
#        [2169.],
#        [2182.],
#        [2259.],
#        [2263.],
#        [2317.],
#        [2317.],
#        [2353.],
#        [2343.],
#        [2362.],
#        [2403.],
#        [2414.],
#        [2440.],
#        [2465.],
#        [2711.],
#        [2729.],
#        [2723.],
#        [2720.],
#        [2752.],
#        [2772.],
#        [2760.],
#        [2703.],
#        [2698.],
#        [2645.],
#        [2659.],
#        [2701.],
#        [2719.],
#        [2718.],
#        [2617.],
#        [2566.],
#        [2507.],
#        [2533.],
#        [2415.],
#        [2604.],
#        [2579.],
#        [2549.],
#        [2526.],
#        [2481.],
#        [2447.],
#        [2468.],
#        [2371.],
#        [2335.],
#        [2286.],
#        [2204.],
#        [2131.],
#        [2118.],
#        [2163.],
#        [2142.],
#        [2125.],
#        [2086.],
#        [2062.],
#        [2055.],
#        [2077.],
#        [2042.],
#        [2024.],
#        [2042.],
#        [1995.],
#        [1956.],
#        [1912.],
#        [1879.],
#        [1879.],
#        [1903.],
#        [1925.],
#        [1715.],
#        [1619.],
#        [1562.],
#        [1507.],
#        [1572.],
#        [1651.],
#        [1658.],
#        [1608.],
#        [1577.],
#        [1595.],
#        [1572.],
#        [1562.],
#        [1544.],
#        [1560.],
#        [1506.],
#        [1509.],
#        [1511.],
#        [1518.],
#        [1495.],
#        [1507.],
#        [1547.],
#        [1533.],
#        [1501.],
#        [1485.],
#        [1515.],
#        [1609.],
#        [1646.],
#        [1638.],
#        [1655.],
#        [1667.],
#        [1646.],
#        [1666.],
#        [1755.],
#        [1776.],
#        [1769.],
#        [1739.],
#        [1791.],
#        [1762.],
#        [1800.],
#        [2045.],
#        [2090.],
#        [2147.],
#        [2180.],
#        [2230.],
#        [2176.],
#        [2301.],
#        [2287.],
#        [2347.],
#        [2403.],
#        [2477.],
#        [2502.],
#        [2553.],
#        [2637.],
#        [2733.],
#        [2832.],
#        [2877.],
#        [2850.],
#        [2947.],
#        [2977.],
#        [3110.],
#        [3201.],
#        [3367.],
#        [3622.],
#        [3769.],
#        [3945.],
#        [3939.],
#        [4166.],
#        [4379.],
#        [4701.],
#        [4859.],
#        [5055.],
#        [5103.],
#        [5233.],
#        [5458.],
#        [5630.],
#        [5990.],
#        [5986.],
#        [6030.],
#        [6148.],
#        [6245.],
#        [6520.],
#        [6649.],
#        [6855.],
#        [6867.],
#        [6999.],
#        [7006.],
#        [7095.],
#        [7073.],
#        [7245.],
#        [7624.],
#        [7442.],
#        [7489.]])

# %%
print(X.shape, y.shape)
# Out:
# (261, 5) (261, 1)

# %% [markdown]
# ## Model - LinearRegression

# %%
# Split the data to testing and training
X_train, X_test, y_train, y_test = train_test_split(X, y,)

# %%
X_train
# Out:
#             hospitalizedIncrease  hospitalizedCurrently  positive  \
# date
# 2020-10-07                  2140                33584.0   7476473
# 2020-10-17                  1528                37474.0   8028462
# 2020-08-28                  1627                37351.0   5860476
# 2020-05-15                  1313                44551.0   1446350
# 2020-08-13                  2651                47322.0   5205005
# ...                          ...                    ...       ...
# 2020-07-01                  1433                36569.0   2674988
# 2020-08-30                   662                35801.0   5943723
# 2020-08-17                  1274                43596.0   5397641
# 2020-11-08                  1467                56942.0   9876830
# 2020-10-18                   813                36536.0   8076742
#
#             positiveIncrease  recovered
# date
# 2020-10-07             50588  2997942.0
# 2020-10-17             57355  3218561.0
# 2020-08-28             46121  2116889.0
# 2020-05-15             25422   250665.0
# 2020-08-13             51621  1773505.0
# ...                      ...        ...
# 2020-07-01             51001   822580.0
# 2020-08-30             39285  2152344.0
# 2020-08-17             37411  1864220.0
# 2020-11-08            110306  3879255.0
# 2020-10-18             48280  3231947.0
#
# [195 rows x 5 columns]

# %%
# Choose the model
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
# model.fit(X_train, y_train)

# %%
# print(f"Training Data Score: {model.score(X_train, y_train)}")
# print(f"Testing Data Score: {model.score(X_test, y_test)}")

# %%
# print('Weight coefficients:', model.coef_)
# print('y-axis intercept:', model.intercept_)

# %% [markdown]
# ### Skaling the data using StandardScaler, and plotting a residual plot

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
# X_train = X_scaler.inverse_transform(X_train_scaled)
# X_train

# %%
y_train_scaled.shape
# Out:
# (195, 1)

# %%
fig1 = plt.figure(figsize=(12, 6))
axes1 = fig1.add_subplot(1, 2, 1)
axes2 = fig1.add_subplot(1, 2, 2)

axes1.set_title("Original Data")
axes2.set_title("Scaled Data")

maxx = X_train["positive"].max()
maxy = y_train.max()
axes1.set_xlim(-maxx + 1, maxx + 1)
axes1.set_ylim(-maxy + 1, maxy + 1)

axes2.set_xlim(-2, 2)
axes2.set_ylim(-2, 2)

def set_axes(ax):
    ax.spines['left'].set_position('center')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('center')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
set_axes(axes1)
set_axes(axes2)

axes1.scatter(X_train["positive"], y_train)
axes2.scatter(X_train_scaled[:,0], y_train_scaled[:])

# %% [markdown]
# ###  Fit the Model to the scaled training data and make predictions using the scaled test data

# %%
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
print(f"Training scaled Data Score: {model.score(X_train_scaled, y_train_scaled)}")
print(f"Testing scaled Data Score: {model.score(X_test_scaled, y_test_scaled)}")
print('Weight coefficients:', model.coef_)
print('y-axis intercept:', model.intercept_)
# Out:
# Training scaled Data Score: 0.7259926562252865
# Testing scaled Data Score: 0.8012022731094567
# Weight coefficients: [[ 0.02023753  1.42399078 -3.41957381 -0.5577957   3.20235188]]
# y-axis intercept: [-3.10408421e-17]

# %% [markdown]
# ## Quantify the model using scaled data

# %%
from sklearn.metrics import mean_squared_error

predictions = model.predict(X_test_scaled)
MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.19388111512846545, R2: 0.8012022731094567

# %%
X_scaled = X_scaler.transform(X)
predictions = model.predict(X_scaled)
print(f"True output:{y[0]}")
print(f"Predicted output:{y_scaler.inverse_transform(predictions[0]).round(2)}") 
print(f"Prediction Error:{y_scaler.inverse_transform(predictions[0]).round(2)-y[0]}")
# Out:
# True output:[258.]
# Predicted output:[105.9]
# Prediction Error:[-152.1]

# %%
predicted_y = y_scaler.inverse_transform(predictions).round(2)
predicted_y.reshape(1,-1).tolist()[0]
# Out:
# [105.9,
#  475.56,
#  626.99,
#  828.38,
#  996.44,
#  1209.56,
#  1521.98,
#  1722.66,
#  1979.65,
#  2516.65,
#  2864.17,
#  3280.29,
#  4212.59,
#  4414.06,
#  5047.09,
#  5307.43,
#  5612.46,
#  5619.26,
#  5784.35,
#  6145.62,
#  6085.87,
#  5958.29,
#  5839.52,
#  5769.94,
#  5559.74,
#  5585.23,
#  5964.42,
#  5862.84,
#  5765.13,
#  5429.0,
#  5379.3,
#  5366.26,
#  5444.42,
#  5386.61,
#  5368.18,
#  5119.59,
#  5169.57,
#  4986.39,
#  4848.0,
#  4866.27,
#  4949.28,
#  4782.11,
#  4598.03,
#  4387.72,
#  4195.73,
#  4013.48,
#  4074.06,
#  4083.72,
#  4034.02,
#  3792.08,
#  3579.41,
#  3512.39,
#  3355.67,
#  3334.46,
#  3344.58,
#  3304.64,
#  3146.43,
#  3156.21,
#  2961.83,
#  2907.34,
#  2920.56,
#  3248.74,
#  2979.16,
#  3144.67,
#  2971.36,
#  2810.48,
#  2799.45,
#  2792.78,
#  2717.02,
#  2652.67,
#  2513.96,
#  2483.7,
#  2414.76,
#  2408.27,
#  2415.9,
#  2425.7,
#  2318.88,
#  2152.17,
#  2048.26,
#  1893.28,
#  1878.18,
#  1957.04,
#  1908.83,
#  1924.76,
#  1833.53,
#  1766.09,
#  1635.72,
#  1699.12,
#  1844.0,
#  1879.33,
#  1860.77,
#  1904.75,
#  1755.31,
#  1840.14,
#  1820.29,
#  2019.4,
#  2064.23,
#  2112.03,
#  2305.93,
#  2282.33,
#  2264.88,
#  2479.61,
#  2715.82,
#  2753.83,
#  2656.5,
#  2805.79,
#  3619.73,
#  3741.78,
#  3753.77,
#  3999.83,
#  4077.4,
#  4100.08,
#  4113.15,
#  3976.62,
#  4154.15,
#  4110.16,
#  4335.57,
#  4325.7,
#  4231.27,
#  4177.07,
#  4092.68,
#  4190.33,
#  4154.5,
#  4311.33,
#  4045.85,
#  3981.38,
#  3751.21,
#  3629.21,
#  3612.87,
#  3757.01,
#  3717.34,
#  3680.79,
#  3717.52,
#  3658.74,
#  3352.79,
#  3215.82,
#  3092.67,
#  3229.84,
#  3020.56,
#  2996.88,
#  2970.53,
#  2643.88,
#  2532.67,
#  2669.43,
#  2762.13,
#  2770.44,
#  2672.95,
#  2531.5,
#  2332.85,
#  2203.9,
#  2217.59,
#  2276.8,
#  2313.22,
#  2163.04,
#  2016.65,
#  1935.92,
#  1872.99,
#  1848.14,
#  2022.7,
#  1800.81,
#  2142.93,
#  1782.23,
#  1541.71,
#  1600.26,
#  1676.64,
#  1741.24,
#  1958.41,
#  1883.65,
#  1734.69,
#  1432.59,
#  1389.91,
#  1408.26,
#  1492.11,
#  1534.71,
#  1463.14,
#  1337.51,
#  1195.54,
#  1173.75,
#  1281.2,
#  1270.93,
#  1204.19,
#  1501.53,
#  1490.76,
#  1187.19,
#  1320.77,
#  1552.32,
#  1603.59,
#  1727.86,
#  1651.68,
#  1618.82,
#  1497.18,
#  1373.7,
#  1602.11,
#  1826.98,
#  1933.87,
#  1952.23,
#  1961.9,
#  1969.05,
#  1908.38,
#  2084.64,
#  2279.87,
#  2295.0,
#  2307.78,
#  2161.48,
#  2030.57,
#  2239.69,
#  2259.54,
#  2330.03,
#  2449.36,
#  2573.72,
#  2423.44,
#  2475.15,
#  2259.77,
#  2551.27,
#  2795.27,
#  2777.56,
#  2737.88,
#  2657.7,
#  2503.16,
#  2695.79,
#  2997.72,
#  3007.46,
#  3144.49,
#  3000.04,
#  2848.28,
#  2773.68,
#  2774.55,
#  3199.71,
#  3334.58,
#  3402.3,
#  3463.78,
#  3499.69,
#  3161.16,
#  3395.97,
#  3744.79,
#  4074.77,
#  4349.0,
#  4477.0,
#  4185.03,
#  4052.16,
#  4423.87,
#  4818.72,
#  5250.15,
#  5205.78,
#  5318.2,
#  6441.87,
#  4980.55,
#  6045.71,
#  6567.35,
#  6761.49,
#  6554.83,
#  6400.99,
#  6133.27,
#  5777.22,
#  6029.9,
#  6660.13,
#  6757.56,
#  6305.15,
#  6730.06,
#  6682.74,
#  6650.08]

# %%
predicted_y = y_scaler.inverse_transform(predictions).round(2)

# %%
sns.set(style='white')

plt.figure(figsize=(10, 5), dpi=100)
plt.plot(df_Covid_data.index, predicted_y, label="Predicted", linewidth=1, marker='.', markersize=5, color='blue')
plt.plot(df_Covid_data.index, df_Covid_data['onVentilatorCurrently'], label="Actual", linewidth=1, marker='.', markersize=5, color='red')
# plt.plot(dc.index, dc["Error"], label="Error", linewidth=1, marker='.', markersize=10, color='green')


plt.xticks(df_Covid_data.index[::10], rotation=90)
plt.title('Actual vs Predicted')
plt.xlabel('date')
plt.ylabel('Used Ventilators')

plt.legend()
#plt.savefig('covid_outbreak.png', dpi=100)
plt.show()

# %% [markdown]
# # Model 2 Random Forest Regressor

# %%
## Model 2
#Import necessary libraries
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score

# %%
y_train_scaled_1d = y_train_scaled .ravel()
y_test_scaled_1d = y_test_scaled .ravel()

# %%
rg = RandomForestRegressor(n_estimators=40)
rg.fit(X_train_scaled, y_train_scaled_1d)
# Out:
# RandomForestRegressor(n_estimators=40)

# %%
print(f"Training scaled Data Score: {rg.score(X_train_scaled, y_train_scaled)}")
print(f"Testing scaled Data Score: {rg.score(X_test_scaled, y_test_scaled)}")
# Out:
# Training scaled Data Score: 0.995512234437085
# Testing scaled Data Score: 0.9634223510220403

# %%
# Build residual plot
plt.scatter(rg.predict(X_train_scaled), rg.predict(X_train_scaled) - y_train_scaled_1d, c="blue", label="Training Data")
plt.scatter(rg.predict(X_test_scaled), rg.predict(X_test_scaled) - y_test_scaled_1d, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled_1d.min(), xmax=y_test_scaled_1d.max())
plt.title("Residual Plot")
plt.show()

# %%
predictions_rg = rg.predict(X_scaled)
print(f"True output:{y}")
print(f"Predicted output:{y_scaler.inverse_transform(predictions_rg).round(2)}") 
print(f"Prediction Error:{y_scaler.inverse_transform(predictions_rg).round(2)-y}")
# Out:
# True output:[[ 258.]
#  [ 324.]
#  [ 390.]
#  [ 439.]
#  [ 451.]
#  [ 507.]
#  [ 561.]
#  [ 574.]
#  [ 623.]
#  [ 656.]
#  [ 652.]
#  [2961.]
#  [4076.]
#  [4131.]
#  [5794.]
#  [5937.]
#  [5978.]
#  [5968.]
#  [6168.]
#  [5975.]
#  [6032.]
#  [5940.]
#  [6096.]
#  [5729.]
#  [5603.]
#  [5567.]
#  [5514.]
#  [5474.]
#  [5464.]
#  [5187.]
#  [5266.]
#  [5121.]
#  [4867.]
#  [4760.]
#  [4796.]
#  [4712.]
#  [4707.]
#  [4845.]
#  [4761.]
#  [4848.]
#  [4818.]
#  [4753.]
#  [7070.]
#  [6788.]
#  [6551.]
#  [6395.]
#  [6350.]
#  [6352.]
#  [6156.]
#  [5940.]
#  [5746.]
#  [5529.]
#  [5467.]
#  [5257.]
#  [5032.]
#  [4911.]
#  [4868.]
#  [4716.]
#  [4620.]
#  [4383.]
#  [4237.]
#  [4215.]
#  [4222.]
#  [4080.]
#  [4032.]
#  [4004.]
#  [3669.]
#  [3950.]
#  [3852.]
#  [3749.]
#  [3665.]
#  [3523.]
#  [3476.]
#  [3298.]
#  [3240.]
#  [3090.]
#  [3020.]
#  [2886.]
#  [2734.]
#  [2726.]
#  [2716.]
#  [2640.]
#  [2594.]
#  [2588.]
#  [2520.]
#  [2434.]
#  [2380.]
#  [2321.]
#  [2299.]
#  [2293.]
#  [2248.]
#  [2214.]
#  [2075.]
#  [2159.]
#  [2077.]
#  [2011.]
#  [2044.]
#  [2098.]
#  [2105.]
#  [2049.]
#  [1982.]
#  [2080.]
#  [2105.]
#  [2098.]
#  [2172.]
#  [2127.]
#  [2197.]
#  [2169.]
#  [2182.]
#  [2259.]
#  [2263.]
#  [2317.]
#  [2317.]
#  [2353.]
#  [2343.]
#  [2362.]
#  [2403.]
#  [2414.]
#  [2440.]
#  [2465.]
#  [2711.]
#  [2729.]
#  [2723.]
#  [2720.]
#  [2752.]
#  [2772.]
#  [2760.]
#  [2703.]
#  [2698.]
#  [2645.]
#  [2659.]
#  [2701.]
#  [2719.]
#  [2718.]
#  [2617.]
#  [2566.]
#  [2507.]
#  [2533.]
#  [2415.]
#  [2604.]
#  [2579.]
#  [2549.]
#  [2526.]
#  [2481.]
#  [2447.]
#  [2468.]
#  [2371.]
#  [2335.]
#  [2286.]
#  [2204.]
#  [2131.]
#  [2118.]
#  [2163.]
#  [2142.]
#  [2125.]
#  [2086.]
#  [2062.]
#  [2055.]
#  [2077.]
#  [2042.]
#  [2024.]
#  [2042.]
#  [1995.]
#  [1956.]
#  [1912.]
#  [1879.]
#  [1879.]
#  [1903.]
#  [1925.]
#  [1715.]
#  [1619.]
#  [1562.]
#  [1507.]
#  [1572.]
#  [1651.]
#  [1658.]
#  [1608.]
#  [1577.]
#  [1595.]
#  [1572.]
#  [1562.]
#  [1544.]
#  [1560.]
#  [1506.]
#  [1509.]
#  [1511.]
#  [1518.]
#  [1495.]
#  [1507.]
#  [1547.]
#  [1533.]
#  [1501.]
#  [1485.]
#  [1515.]
#  [1609.]
#  [1646.]
#  [1638.]
#  [1655.]
#  [1667.]
#  [1646.]
#  [1666.]
#  [1755.]
#  [1776.]
#  [1769.]
#  [1739.]
#  [1791.]
#  [1762.]
#  [1800.]
#  [2045.]
#  [2090.]
#  [2147.]
#  [2180.]
#  [2230.]
#  [2176.]
#  [2301.]
#  [2287.]
#  [2347.]
#  [2403.]
#  [2477.]
#  [2502.]
#  [2553.]
#  [2637.]
#  [2733.]
#  [2832.]
#  [2877.]
#  [2850.]
#  [2947.]
#  [2977.]
#  [3110.]
#  [3201.]
#  [3367.]
#  [3622.]
#  [3769.]
#  [3945.]
#  [3939.]
#  [4166.]
#  [4379.]
#  [4701.]
#  [4859.]
#  [5055.]
#  [5103.]
#  [5233.]
#  [5458.]
#  [5630.]
#  [5990.]
#  [5986.]
#  [6030.]
#  [6148.]
#  [6245.]
#  [6520.]
#  [6649.]
#  [6855.]
#  [6867.]
#  [6999.]
#  [7006.]
#  [7095.]
#  [7073.]
#  [7245.]
#  [7624.]
#  [7442.]
#  [7489.]]
# Predicted output:[1396.53 1255.03  578.08  697.8   438.58  514.45  547.65  587.8   614.62
#   716.67  870.95 1199.33 4242.95 4713.18 5816.85 5933.67 5973.72 5980.52
#  6115.72 5970.35 6009.03 5975.7  5985.85 5745.28 5619.67 5612.42 5561.52
#  5433.17 5386.15 5230.62 4972.85 4864.1  4924.08 4819.85 4817.28 4770.1
#  4869.35 4944.12 5052.33 5149.75 5210.5  5288.45 6186.62 6175.88 6277.05
#  6265.98 6309.05 6302.1  6098.75 5653.98 5615.92 5365.45 5315.33 5181.1
#  5091.9  4910.68 4321.48 4385.15 4143.45 4306.15 4225.82 4225.12 4231.6
#  4048.92 3922.35 3779.23 3780.5  3804.9  3826.95 3764.32 3610.1  3377.42
#  3305.62 3326.65 3293.7  3254.05 2974.42 2870.02 2786.32 2649.62 2727.6
#  2914.55 2655.8  2613.85 2535.15 2435.05 2377.5  2316.4  2318.   2259.35
#  2216.52 2177.4  2109.63 2149.73 2123.4  2100.05 2056.83 2079.65 2083.65
#  2054.05 2017.35 2097.93 2126.43 2139.6  2177.32 2206.12 2201.17 2348.75
#  2197.53 2248.58 2275.63 2313.13 2324.28 2342.72 2349.65 2358.97 2389.43
#  2417.45 2529.45 2777.08 2859.72 2728.35 2720.18 2709.88 2807.48 2749.55
#  2743.15 2715.55 2716.2  2655.73 2667.58 2786.45 2700.18 2710.75 2678.85
#  2590.88 2585.7  2583.43 2602.52 2592.15 2569.8  2529.07 2508.25 2475.93
#  2739.32 2462.43 2358.23 2253.63 2222.17 2132.4  2129.57 2135.55 2158.75
#  2135.7  2108.5  2094.65 2071.4  2066.1  2071.87 2082.35 2061.12 2016.1
#  1984.12 1956.15 1906.38 1880.63 2238.15 1894.65 1875.28 1723.55 1614.45
#  1603.75 1599.98 1583.73 1583.75 1620.17 1593.55 1577.3  1575.17 1574.95
#  1579.1  1562.98 1547.48 1513.02 1508.1  1508.65 1511.28 1501.57 1522.95
#  1536.   1526.72 1508.85 1511.75 1568.48 1626.78 1663.32 1665.7  1677.98
#  1670.1  1660.4  1673.3  1742.88 1744.77 1767.88 1770.4  1782.03 1751.93
#  1818.98 2016.18 2110.18 2145.03 2204.23 2244.98 2230.1  2310.55 2454.4
#  2452.65 2442.45 2486.18 2518.07 2548.8  2610.6  2696.08 2785.9  2857.12
#  2876.15 3012.82 2980.45 3051.58 3312.62 3612.42 3780.38 3929.07 4015.77
#  4094.45 4252.85 4365.58 4668.2  4862.42 4976.65 5061.25 5181.35 5257.45
#  5659.88 5991.45 5857.68 6006.37 6090.65 6150.7  6493.38 6651.35 6822.45
#  6897.12 6977.32 7000.72 6911.32 7015.62 7220.72 7469.7  7393.67 7461.93]
# Prediction Error:[[ 1138.53   997.03   320.08 ...  7211.7   7135.67  7203.93]
#  [ 1072.53   931.03   254.08 ...  7145.7   7069.67  7137.93]
#  [ 1006.53   865.03   188.08 ...  7079.7   7003.67  7071.93]
#  ...
#  [-6227.47 -6368.97 -7045.92 ...  -154.3   -230.33  -162.07]
#  [-6045.47 -6186.97 -6863.92 ...    27.7    -48.33    19.93]
#  [-6092.47 -6233.97 -6910.92 ...   -19.3    -95.33   -27.07]]

# %%
predicted_y_rg = y_scaler.inverse_transform(predictions_rg).round(2)

# %%
sns.set(style='white')

plt.figure(figsize=(10, 5), dpi=100)
plt.plot(df_Covid_data.index, predicted_y_rg, label="Predicted", linewidth=1, marker='.', markersize=5, color='blue')
plt.plot(df_Covid_data.index, df_Covid_data['onVentilatorCurrently'], label="Actual", linewidth=1, marker='.', markersize=5, color='red')
# plt.plot(dc.index, dc["Error"], label="Error", linewidth=1, marker='.', markersize=10, color='green')


plt.xticks(df_Covid_data.index[::10], rotation=90)
plt.title('Actual vs Predicted')
plt.xlabel('date')
plt.ylabel('Used Ventilators')

plt.legend()
#plt.savefig('covid_outbreak.png', dpi=100)
plt.show()

# %% [markdown]
# ### The random forest regresor scored great with R2 of 0.99, however the random forest regressor is unable to discover trends that would enable it in extrapolating values that fall outside the training set. Having in mind that the currnet covid cases are raising and we are seeing new high every day, this  model willl be abandoned.
#
# #### For more info see https://neptune.ai/blog/random-forest-regression-when-does-it-fail-and-why

# %% [markdown]
# ## Model 3, Linear regression with more data columns added

# %%
df_Covid_data_Offset = df_Covid_data[['hospitalizedIncrease','hospitalizedCurrently','positive',\
             'positiveIncrease','recovered','onVentilatorCurrently']]
df_Covid_data_Offset
# Out:
#             hospitalizedIncrease  hospitalizedCurrently  positive  \
# date
# 2020-03-26                  2478                 7805.0     92976
# 2020-03-27                  2572                10978.0    112220
# 2020-03-28                  2409                12409.0    131826
# 2020-03-29                  2794                14055.0    151270
# 2020-03-30                  2472                15917.0    172740
# ...                          ...                    ...       ...
# 2020-12-07                  3614               102148.0  14718817
# 2020-12-08                  4309               104590.0  14934152
# 2020-12-09                  5424               106705.0  15145172
# 2020-12-10                  4335               107258.0  15360841
# 2020-12-11                  5444               108108.0  15592946
#
#             positiveIncrease  recovered  onVentilatorCurrently
# date
# 2020-03-26             17734       97.0                  258.0
# 2020-03-27             19244     2418.0                  324.0
# 2020-03-28             19606     3145.0                  390.0
# 2020-03-29             19444     4076.0                  439.0
# 2020-03-30             21470     4560.0                  451.0
# ...                      ...        ...                    ...
# 2020-12-07            180219  5714557.0                 7073.0
# 2020-12-08            215335  5788509.0                 7245.0
# 2020-12-09            211020  5891885.0                 7624.0
# 2020-12-10            215669  5985047.0                 7442.0
# 2020-12-11            232105  6135314.0                 7489.0
#
# [261 rows x 6 columns]

# %%
# Function for shifting row values
def add_data_shift (data_frame, column_name, x):
    for i in x:
        shift_i = column_name + '_shifted_'+str(i)
        data_frame[shift_i] = data_frame[column_name]
        data_frame[shift_i] = data_frame[shift_i].shift(0-i)
    return(data_frame)

# %%
add_data_shift (df_Covid_data_Offset, "positive", [1,3,7,10])
# Out:
# C:\Users\stoja\Anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\stoja\Anaconda3\envs\PythonAdv\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#             hospitalizedIncrease  hospitalizedCurrently  positive  \
# date
# 2020-03-26                  2478                 7805.0     92976
# 2020-03-27                  2572                10978.0    112220
# 2020-03-28                  2409                12409.0    131826
# 2020-03-29                  2794                14055.0    151270
# 2020-03-30                  2472                15917.0    172740
# ...                          ...                    ...       ...
# 2020-12-07                  3614               102148.0  14718817
# 2020-12-08                  4309               104590.0  14934152
# 2020-12-09                  5424               106705.0  15145172
# 2020-12-10                  4335               107258.0  15360841
# 2020-12-11                  5444               108108.0  15592946
#
#             positiveIncrease  recovered  onVentilatorCurrently  \
# date
# 2020-03-26             17734       97.0                  258.0
# 2020-03-27             19244     2418.0                  324.0
# 2020-03-28             19606     3145.0                  390.0
# 2020-03-29             19444     4076.0                  439.0
# 2020-03-30             21470     4560.0                  451.0
# ...                      ...        ...                    ...
# 2020-12-07            180219  5714557.0                 7073.0
# 2020-12-08            215335  5788509.0                 7245.0
# 2020-12-09            211020  5891885.0                 7624.0
# 2020-12-10            215669  5985047.0                 7442.0
# 2020-12-11            232105  6135314.0                 7489.0
#
#             positive_shifted_1  positive_shifted_3  positive_shifted_7  \
# date
# 2020-03-26            112220.0            151270.0            252085.0
# 2020-03-27            131826.0            172740.0            283923.0
# 2020-03-28            151270.0            197924.0            316808.0
# 2020-03-29            172740.0            224040.0            342463.0
# 2020-03-30            197924.0            252085.0            370872.0
# ...                        ...                 ...                 ...
# 2020-12-07          14934152.0          15360841.0                 NaN
# 2020-12-08          15145172.0          15592946.0                 NaN
# 2020-12-09          15360841.0                 NaN                 NaN
# 2020-12-10          15592946.0                 NaN                 NaN
# 2020-12-11                 NaN                 NaN                 NaN
#
# 2020-12-09                              NaN                              NaN
# 2020-12-10                              NaN                              NaN
# 2020-12-11                              NaN                              NaN
#
#             hospitalizedCurrently_shifted_10  recovered_shifted_1  \
# date
# 2020-03-26                           32180.0               2418.0
# 2020-03-27                           36159.0               3145.0
# 2020-03-28                           43849.0               4076.0
# 2020-03-29                           45515.0               4560.0
# 2020-03-30                           51313.0               5666.0
# ...                                      ...                  ...
# 2020-12-07                               NaN            5788509.0
# 2020-12-08                               NaN            5891885.0
# 2020-12-09                               NaN            5985047.0
# 2020-12-10                               NaN            6135314.0
# 2020-12-11                               NaN                  NaN
#
#             recovered_shifted_3  recovered_shifted_7  recovered_shifted_10
# date
# 2020-03-26               4076.0               8586.0               14589.0
# 2020-03-27               4560.0              10861.0               16557.0
# 2020-03-28               5666.0              12844.0               18481.0
# 2020-03-29               7084.0              14589.0               21132.0
# 2020-03-30               8586.0              16557.0               24835.0
# ...                         ...                  ...                   ...
# 2020-12-07            5985047.0                  NaN                   NaN
# 2020-12-08            6135314.0                  NaN                   NaN
# 2020-12-09                  NaN                  NaN                   NaN
# 2020-12-10                  NaN                  NaN                   NaN
# 2020-12-11                  NaN                  NaN                   NaN
#
# [261 rows x 18 columns]

# %%
# df_Covid_data_Offset.to_csv('National_Covid_Data_Offset_'+today.strftime("%Y-%m-%d")+'.csv')

# %%
df_Covid_data_Offset = df_Covid_data_Offset.dropna()

# %%
print("Size/Shape of the dataset",df_Covid_data_Offset.shape)
print("Checking for null values:\n",df_Covid_data_Offset.isnull().sum())
print("Checking Data-type:",df_Covid_data_Offset.dtypes)
# Out:
# Size/Shape of the dataset (251, 18)
# Checking for null values:
#  hospitalizedIncrease                0
# hospitalizedCurrently               0
# positive                            0
# positiveIncrease                    0
# recovered                           0
# onVentilatorCurrently               0
# positive_shifted_1                  0
# positive_shifted_3                  0
# positive_shifted_7                  0
# positive_shifted_10                 0
# hospitalizedCurrently_shifted_1     0
# hospitalizedCurrently_shifted_3     0
# hospitalizedCurrently_shifted_7     0
# hospitalizedCurrently_shifted_10    0
# recovered_shifted_1                 0
# recovered_shifted_3                 0
# recovered_shifted_7                 0
# recovered_shifted_10                0
# dtype: int64
# Checking Data-type: hospitalizedIncrease                  int64
# hospitalizedCurrently               float64
# positive                              int64
# positiveIncrease                      int64
# recovered                           float64
# onVentilatorCurrently               float64
# positive_shifted_1                  float64
# positive_shifted_3                  float64
# positive_shifted_7                  float64
# positive_shifted_10                 float64
# hospitalizedCurrently_shifted_1     float64
# hospitalizedCurrently_shifted_3     float64
# hospitalizedCurrently_shifted_7     float64
# hospitalizedCurrently_shifted_10    float64
# recovered_shifted_1                 float64
# recovered_shifted_3                 float64
# recovered_shifted_7                 float64
# recovered_shifted_10                float64
# dtype: object

# %%
X = df_Covid_data_Offset[['hospitalizedIncrease','hospitalizedCurrently','positive',\
             'positiveIncrease','recovered',"positive_shifted_1", "positive_shifted_3","positive_shifted_7","positive_shifted_10",\
                  "hospitalizedCurrently_shifted_1","hospitalizedCurrently_shifted_3","hospitalizedCurrently_shifted_7","hospitalizedCurrently_shifted_10",\
                  "recovered_shifted_1", "recovered_shifted_3","recovered_shifted_7","recovered_shifted_10"]]
y = df_Covid_data_Offset['onVentilatorCurrently'].values.reshape(-1,1)

# %%
# From this step on, the same process is followed

# %%
print(X.shape, y.shape)
# Out:
# (251, 17) (251, 1)

# %%
# Split the data to testing and training
X_train, X_test, y_train, y_test = train_test_split(X, y,)

# %%
# Choose the model
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
fig1 = plt.figure(figsize=(12, 6))
axes1 = fig1.add_subplot(1, 2, 1)
axes2 = fig1.add_subplot(1, 2, 2)

axes1.set_title("Original Data")
axes2.set_title("Scaled Data")

maxx = X_train["positive"].max()
maxy = y_train.max()
axes1.set_xlim(-maxx + 1, maxx + 1)
axes1.set_ylim(-maxy + 1, maxy + 1)

axes2.set_xlim(-2, 2)
axes2.set_ylim(-2, 2)

def set_axes(ax):
    ax.spines['left'].set_position('center')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('center')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
set_axes(axes1)
set_axes(axes2)

axes1.scatter(X_train["positive"], y_train)
axes2.scatter(X_train_scaled[:,0], y_train_scaled[:])

# %%
X.dtypes
# Out:
# hospitalizedIncrease                  int64
# hospitalizedCurrently               float64
# positive                              int64
# positiveIncrease                      int64
# recovered                           float64
# positive_shifted_1                  float64
# positive_shifted_3                  float64
# positive_shifted_7                  float64
# positive_shifted_10                 float64
# hospitalizedCurrently_shifted_1     float64
# hospitalizedCurrently_shifted_3     float64
# hospitalizedCurrently_shifted_7     float64
# hospitalizedCurrently_shifted_10    float64
# recovered_shifted_1                 float64
# recovered_shifted_3                 float64
# recovered_shifted_7                 float64
# recovered_shifted_10                float64
# dtype: object

# %%
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
print(f"Training scaled Data Score: {model.score(X_train_scaled, y_train_scaled)}")
print(f"Testing scaled Data Score: {model.score(X_test_scaled, y_test_scaled)}")
print('Weight coefficients:', model.coef_)
print('y-axis intercept:', model.intercept_)
# Out:
# Training scaled Data Score: 0.8360058664055934
# Testing scaled Data Score: 0.7971528246223771
# Weight coefficients: [[-1.62542304e-02  1.80238635e+00 -2.11826957e+00  2.04094340e-02
#    7.27204432e+00  1.28181243e+01 -2.20034313e+01 -1.11058017e+01
#    1.13859167e+01 -1.62808388e-01  4.67830501e-01 -7.84812258e-01
#   -5.82679316e-01 -3.10105227e+00 -9.77566737e+00  4.88770073e-01
#    1.57647973e+01]]
# y-axis intercept: [-5.98211141e-17]

# %%
from sklearn.metrics import mean_squared_error

predictions = model.predict(X_test_scaled)
MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.23268799909099214, R2: 0.7971528246223771

# %%
X_scaled = X_scaler.transform(X)
predictions = model.predict(X_scaled)
print(f"True output:{y[0]}")
print(f"Predicted output:{y_scaler.inverse_transform(predictions[0]).round(2)}") 
print(f"Prediction Error:{y_scaler.inverse_transform(predictions[0]).round(2)-y[0]}")
# Out:
# True output:[258.]
# Predicted output:[1143.84]
# Prediction Error:[885.84]

# %%
predicted_y = y_scaler.inverse_transform(predictions).round(2)

# %%
sns.set(style='white')

plt.figure(figsize=(10, 5), dpi=100)
plt.plot(df_Covid_data_Offset.index, predicted_y, label="Predicted", linewidth=1, marker='.', markersize=5, color='blue')
plt.plot(df_Covid_data_Offset.index, df_Covid_data_Offset['onVentilatorCurrently'], label="Actual", linewidth=1, marker='.', markersize=5, color='red')
# plt.plot(dc.index, dc["Error"], label="Error", linewidth=1, marker='.', markersize=10, color='green')


plt.xticks(df_Covid_data.index[::10], rotation=90)
plt.title('Actual vs Predicted')
plt.xlabel('date')
plt.ylabel('Used Ventilators')

plt.legend()
#plt.savefig('covid_outbreak.png', dpi=100)
plt.show()

# %% [markdown]
# ### Model 4 Neural Network Model

# %%
# pip install Keras, if needed and not installed before

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
# # define base model
# def baseline_model():
#     # create model
#     model = Sequential()
#     model.add(Dense(17, input_dim=17, kernel_initializer='normal', activation='relu'))
#     model.add(Dense(8, kernel_initializer='normal', activation='relu'))
#     model.add(Dense(1, kernel_initializer='normal'))
#     # Compile model
#     model.compile(loss='mean_squared_error', optimizer='adam')
#     return model
# # evaluate model
# estimator = KerasRegressor(build_fn=baseline_model, epochs=100, batch_size=5, verbose=0)
# kfold = KFold(n_splits=10)
# results = cross_val_score(estimator, X_train_scaled, y_train_scaled, cv=kfold)
# print("Baseline: %.2f (%.2f) MSE" % (results.mean(), results.std()))

# %%
# # define wider model
# def wider_model():
#     # create model
#     model = Sequential()
#     model.add(Dense(17, input_dim=17, kernel_initializer='normal', activation='relu'))
#     model.add(Dense(1, kernel_initializer='normal'))
#     # Compile model
#     model.compile(loss='mean_squared_error', optimizer='adam')
#     return model
# # evaluate model with standardized dataset
# estimators = []
# estimators.append(('standardize', StandardScaler()))
# estimators.append(('mlp', KerasRegressor(build_fn=wider_model, epochs=100, batch_size=5, verbose=0)))
# pipeline = Pipeline(estimators)
# kfold = KFold(n_splits=10)
# results = cross_val_score(pipeline, X, y, cv=kfold)
# print("Wider: %.2f (%.2f) MSE" % (results.mean(), results.std()))

# %%
# create model
model = Sequential()
model.add(Dense(20, input_dim=17, kernel_initializer='normal', activation='relu'))
model.add(Dense(10, kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))
# Compile model
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Fit (train) the model
model.fit(
    X_train_scaled,
    y_train_scaled,
    epochs=3000,
    shuffle=False,
    verbose=2
)
# Out:
# Epoch 1/3000
# 6/6 - 0s - loss: 0.9869
# Epoch 2/3000
# 6/6 - 0s - loss: 0.9779
# Epoch 3/3000
# 6/6 - 0s - loss: 0.9678
# Epoch 4/3000
# 6/6 - 0s - loss: 0.9553
# Epoch 5/3000
# 6/6 - 0s - loss: 0.9397
# Epoch 6/3000
# 6/6 - 0s - loss: 0.9202
# Epoch 7/3000
# 6/6 - 0s - loss: 0.8958
# Epoch 8/3000
# 6/6 - 0s - loss: 0.8663
# Epoch 9/3000
# 6/6 - 0s - loss: 0.8315
# Epoch 10/3000
# 6/6 - 0s - loss: 0.7917
# Epoch 11/3000
# 6/6 - 0s - loss: 0.7480
# Epoch 12/3000
# 6/6 - 0s - loss: 0.7019
# Epoch 13/3000
# 6/6 - 0s - loss: 0.6548
# Epoch 14/3000
# 6/6 - 0s - loss: 0.6081
# Epoch 15/3000
# 6/6 - 0s - loss: 0.5624
# Epoch 16/3000
# 6/6 - 0s - loss: 0.5177
# Epoch 17/3000
# 6/6 - 0s - loss: 0.4752
# Epoch 18/3000
# 6/6 - 0s - loss: 0.4348
# Epoch 19/3000
# 6/6 - 0s - loss: 0.3969
# Epoch 20/3000
# 6/6 - 0s - loss: 0.3619
# Epoch 21/3000
# 6/6 - 0s - loss: 0.3295
# Epoch 22/3000
# 6/6 - 0s - loss: 0.3003
# Epoch 23/3000
# 6/6 - 0s - loss: 0.2740
# Epoch 24/3000
# 6/6 - 0s - loss: 0.2505
# Epoch 25/3000
# 6/6 - 0s - loss: 0.2294
# Epoch 26/3000
# 6/6 - 0s - loss: 0.2099
# Epoch 27/3000
# 6/6 - 0s - loss: 0.1920
# Epoch 28/3000
# 6/6 - 0s - loss: 0.1755
# Epoch 29/3000
# 6/6 - 0s - loss: 0.1601
# Epoch 30/3000
# 6/6 - 0s - loss: 0.1458
# Epoch 31/3000
# 6/6 - 0s - loss: 0.1328
# Epoch 32/3000
# 6/6 - 0s - loss: 0.1212
# Epoch 33/3000
# 6/6 - 0s - loss: 0.1106
# Epoch 34/3000
# 6/6 - 0s - loss: 0.1009
# Epoch 35/3000
# 6/6 - 0s - loss: 0.0921
# Epoch 36/3000
# 6/6 - 0s - loss: 0.0844
# Epoch 37/3000
# 6/6 - 0s - loss: 0.0775
# Epoch 38/3000
# 6/6 - 0s - loss: 0.0716
# Epoch 39/3000
# 6/6 - 0s - loss: 0.0665
# Epoch 40/3000
# 6/6 - 0s - loss: 0.0623
# Epoch 41/3000
# 6/6 - 0s - loss: 0.0588
# Epoch 42/3000
# 6/6 - 0s - loss: 0.0560
# Epoch 43/3000
# 6/6 - 0s - loss: 0.0537
# Epoch 44/3000
# 6/6 - 0s - loss: 0.0518
# Epoch 45/3000
# 6/6 - 0s - loss: 0.0503
# Epoch 46/3000
# 6/6 - 0s - loss: 0.0490
# Epoch 47/3000
# 6/6 - 0s - loss: 0.0478
# Epoch 48/3000
# 6/6 - 0s - loss: 0.0471
# Epoch 49/3000
# 6/6 - 0s - loss: 0.0461
# Epoch 50/3000
# 6/6 - 0s - loss: 0.0454
# Epoch 51/3000
# 6/6 - 0s - loss: 0.0447
# Epoch 52/3000
# 6/6 - 0s - loss: 0.0441
# Epoch 53/3000
# 6/6 - 0s - loss: 0.0436
# Epoch 54/3000
# 6/6 - 0s - loss: 0.0430
# Epoch 55/3000
# 6/6 - 0s - loss: 0.0425
# Epoch 56/3000
# 6/6 - 0s - loss: 0.0420
# Epoch 57/3000
# 6/6 - 0s - loss: 0.0414
# Epoch 58/3000
# 6/6 - 0s - loss: 0.0410
# Epoch 59/3000
# 6/6 - 0s - loss: 0.0406
# Epoch 60/3000
# 6/6 - 0s - loss: 0.0401
# Epoch 61/3000
# 6/6 - 0s - loss: 0.0397
# Epoch 62/3000
# 6/6 - 0s - loss: 0.0393
# Epoch 63/3000
# 6/6 - 0s - loss: 0.0389
# Epoch 64/3000
# 6/6 - 0s - loss: 0.0386
# Epoch 65/3000
# 6/6 - 0s - loss: 0.0383
# Epoch 66/3000
# 6/6 - 0s - loss: 0.0380
# Epoch 67/3000
# 6/6 - 0s - loss: 0.0377
# Epoch 68/3000
# 6/6 - 0s - loss: 0.0374
# Epoch 69/3000
# 6/6 - 0s - loss: 0.0373
# Epoch 70/3000
# 6/6 - 0s - loss: 0.0369
# Epoch 71/3000
# 6/6 - 0s - loss: 0.0367
# Epoch 72/3000
# 6/6 - 0s - loss: 0.0365
# Epoch 73/3000
# 6/6 - 0s - loss: 0.0362
# Epoch 74/3000
# 6/6 - 0s - loss: 0.0360
# Epoch 75/3000
# 6/6 - 0s - loss: 0.0358
# Epoch 76/3000
# 6/6 - 0s - loss: 0.0354
# Epoch 77/3000
# 6/6 - 0s - loss: 0.0353
# Epoch 78/3000
# 6/6 - 0s - loss: 0.0350
# Epoch 79/3000
# 6/6 - 0s - loss: 0.0348
# Epoch 80/3000
# 6/6 - 0s - loss: 0.0345
# Epoch 81/3000
# 6/6 - 0s - loss: 0.0344
# Epoch 82/3000
# 6/6 - 0s - loss: 0.0341
# Epoch 83/3000
# 6/6 - 0s - loss: 0.0339
# Epoch 84/3000
# 6/6 - 0s - loss: 0.0337
# Epoch 85/3000
# 6/6 - 0s - loss: 0.0336
# Epoch 86/3000
# 6/6 - 0s - loss: 0.0334
# Epoch 87/3000
# 6/6 - 0s - loss: 0.0331
# Epoch 88/3000
# 6/6 - 0s - loss: 0.0330
# Epoch 89/3000
# 6/6 - 0s - loss: 0.0328
# Epoch 90/3000
# 6/6 - 0s - loss: 0.0326
# Epoch 91/3000
# 6/6 - 0s - loss: 0.0325
# Epoch 92/3000
# 6/6 - 0s - loss: 0.0323
# Epoch 93/3000
# 6/6 - 0s - loss: 0.0321
# Epoch 94/3000
# 6/6 - 0s - loss: 0.0319
# Epoch 95/3000
# 6/6 - 0s - loss: 0.0317
# Epoch 96/3000
# 6/6 - 0s - loss: 0.0316
# Epoch 97/3000
# 6/6 - 0s - loss: 0.0314
# Epoch 98/3000
# 6/6 - 0s - loss: 0.0312
# Epoch 99/3000
# 6/6 - 0s - loss: 0.0311
# Epoch 100/3000
# 6/6 - 0s - loss: 0.0309
# Epoch 101/3000
# 6/6 - 0s - loss: 0.0308
# Epoch 102/3000
# 6/6 - 0s - loss: 0.0305
# Epoch 103/3000
# 6/6 - 0s - loss: 0.0304
# Epoch 104/3000
# 6/6 - 0s - loss: 0.0302
# Epoch 105/3000
# 6/6 - 0s - loss: 0.0301
# Epoch 106/3000
# 6/6 - 0s - loss: 0.0299
# Epoch 107/3000
# 6/6 - 0s - loss: 0.0297
# Epoch 108/3000
# 6/6 - 0s - loss: 0.0296
# Epoch 109/3000
# 6/6 - 0s - loss: 0.0294
# Epoch 110/3000
# 6/6 - 0s - loss: 0.0293
# Epoch 111/3000
# 6/6 - 0s - loss: 0.0291
# Epoch 112/3000
# 6/6 - 0s - loss: 0.0290
# Epoch 113/3000
# 6/6 - 0s - loss: 0.0288
# Epoch 114/3000
# 6/6 - 0s - loss: 0.0287
# Epoch 115/3000
# 6/6 - 0s - loss: 0.0286
# Epoch 116/3000
# 6/6 - 0s - loss: 0.0284
# Epoch 117/3000
# 6/6 - 0s - loss: 0.0283
# Epoch 118/3000
# 6/6 - 0s - loss: 0.0281
# Epoch 119/3000
# 6/6 - 0s - loss: 0.0280
# Epoch 120/3000
# 6/6 - 0s - loss: 0.0279
# Epoch 121/3000
# 6/6 - 0s - loss: 0.0277
# Epoch 122/3000
# 6/6 - 0s - loss: 0.0276
# Epoch 123/3000
# 6/6 - 0s - loss: 0.0275
# Epoch 124/3000
# 6/6 - 0s - loss: 0.0274
# Epoch 125/3000
# 6/6 - 0s - loss: 0.0273
# Epoch 126/3000
# 6/6 - 0s - loss: 0.0271
# Epoch 127/3000
# 6/6 - 0s - loss: 0.0270
# Epoch 128/3000
# 6/6 - 0s - loss: 0.0269
# Epoch 129/3000
# 6/6 - 0s - loss: 0.0268
# Epoch 130/3000
# 6/6 - 0s - loss: 0.0267
# Epoch 131/3000
# 6/6 - 0s - loss: 0.0266
# Epoch 132/3000
# 6/6 - 0s - loss: 0.0265
# Epoch 133/3000
# 6/6 - 0s - loss: 0.0264
# Epoch 134/3000
# 6/6 - 0s - loss: 0.0263
# Epoch 135/3000
# 6/6 - 0s - loss: 0.0262
# Epoch 136/3000
# 6/6 - 0s - loss: 0.0261
# Epoch 137/3000
# 6/6 - 0s - loss: 0.0260
# Epoch 138/3000
# 6/6 - 0s - loss: 0.0259
# Epoch 139/3000
# 6/6 - 0s - loss: 0.0258
# Epoch 140/3000
# 6/6 - 0s - loss: 0.0257
# Epoch 141/3000
# 6/6 - 0s - loss: 0.0256
# Epoch 142/3000
# 6/6 - 0s - loss: 0.0255
# Epoch 143/3000
# 6/6 - 0s - loss: 0.0254
# Epoch 144/3000
# 6/6 - 0s - loss: 0.0254
# Epoch 145/3000
# 6/6 - 0s - loss: 0.0253
# Epoch 146/3000
# 6/6 - 0s - loss: 0.0252
# Epoch 147/3000
# 6/6 - 0s - loss: 0.0251
# Epoch 148/3000
# 6/6 - 0s - loss: 0.0250
# Epoch 149/3000
# 6/6 - 0s - loss: 0.0250
# Epoch 150/3000
# 6/6 - 0s - loss: 0.0249
# Epoch 151/3000
# 6/6 - 0s - loss: 0.0248
# Epoch 152/3000
# 6/6 - 0s - loss: 0.0247
# Epoch 153/3000
# 6/6 - 0s - loss: 0.0246
# Epoch 154/3000
# 6/6 - 0s - loss: 0.0246
# Epoch 155/3000
# 6/6 - 0s - loss: 0.0245
# Epoch 156/3000
# 6/6 - 0s - loss: 0.0244
# Epoch 157/3000
# 6/6 - 0s - loss: 0.0244
# Epoch 158/3000
# 6/6 - 0s - loss: 0.0243
# Epoch 159/3000
# 6/6 - 0s - loss: 0.0242
# Epoch 160/3000
# 6/6 - 0s - loss: 0.0242
# Epoch 161/3000
# 6/6 - 0s - loss: 0.0241
# Epoch 162/3000
# 6/6 - 0s - loss: 0.0240
# Epoch 163/3000
# 6/6 - 0s - loss: 0.0239
# Epoch 164/3000
# 6/6 - 0s - loss: 0.0239
# Epoch 165/3000
# 6/6 - 0s - loss: 0.0238
# Epoch 166/3000
# 6/6 - 0s - loss: 0.0238
# Epoch 167/3000
# 6/6 - 0s - loss: 0.0237
# Epoch 168/3000
# 6/6 - 0s - loss: 0.0236
# Epoch 169/3000
# 6/6 - 0s - loss: 0.0236
# Epoch 170/3000
# 6/6 - 0s - loss: 0.0235
# Epoch 171/3000
# 6/6 - 0s - loss: 0.0234
# Epoch 172/3000
# 6/6 - 0s - loss: 0.0233
# Epoch 173/3000
# 6/6 - 0s - loss: 0.0233
# Epoch 174/3000
# 6/6 - 0s - loss: 0.0232
# Epoch 175/3000
# 6/6 - 0s - loss: 0.0232
# Epoch 176/3000
# 6/6 - 0s - loss: 0.0231
# Epoch 177/3000
# 6/6 - 0s - loss: 0.0230
# Epoch 178/3000
# 6/6 - 0s - loss: 0.0229
# Epoch 179/3000
# 6/6 - 0s - loss: 0.0229
# Epoch 180/3000
# 6/6 - 0s - loss: 0.0228
# Epoch 181/3000
# 6/6 - 0s - loss: 0.0228
# Epoch 182/3000
# 6/6 - 0s - loss: 0.0227
# Epoch 183/3000
# 6/6 - 0s - loss: 0.0226
# Epoch 184/3000
# 6/6 - 0s - loss: 0.0226
# Epoch 185/3000
# 6/6 - 0s - loss: 0.0225
# Epoch 186/3000
# 6/6 - 0s - loss: 0.0224
# Epoch 187/3000
# 6/6 - 0s - loss: 0.0224
# Epoch 188/3000
# 6/6 - 0s - loss: 0.0223
# Epoch 189/3000
# 6/6 - 0s - loss: 0.0223
# Epoch 190/3000
# 6/6 - 0s - loss: 0.0222
# Epoch 191/3000
# 6/6 - 0s - loss: 0.0222
# Epoch 192/3000
# 6/6 - 0s - loss: 0.0221
# Epoch 193/3000
# 6/6 - 0s - loss: 0.0221
# Epoch 194/3000
# 6/6 - 0s - loss: 0.0220
# Epoch 195/3000
# 6/6 - 0s - loss: 0.0220
# Epoch 196/3000
# 6/6 - 0s - loss: 0.0219
# Epoch 197/3000
# 6/6 - 0s - loss: 0.0218
# Epoch 198/3000
# 6/6 - 0s - loss: 0.0218
# Epoch 199/3000
# 6/6 - 0s - loss: 0.0217
# Epoch 200/3000
# 6/6 - 0s - loss: 0.0217
# Epoch 201/3000
# 6/6 - 0s - loss: 0.0216
# Epoch 202/3000
# 6/6 - 0s - loss: 0.0216
# Epoch 203/3000
# 6/6 - 0s - loss: 0.0215
# Epoch 204/3000
# 6/6 - 0s - loss: 0.0215
# Epoch 205/3000
# 6/6 - 0s - loss: 0.0215
# Epoch 206/3000
# 6/6 - 0s - loss: 0.0214
# Epoch 207/3000
# 6/6 - 0s - loss: 0.0214
# Epoch 208/3000
# 6/6 - 0s - loss: 0.0213
# Epoch 209/3000
# 6/6 - 0s - loss: 0.0213
# Epoch 210/3000
# 6/6 - 0s - loss: 0.0213
# Epoch 211/3000
# 6/6 - 0s - loss: 0.0212
# Epoch 212/3000
# 6/6 - 0s - loss: 0.0212
# Epoch 213/3000
# 6/6 - 0s - loss: 0.0211
# Epoch 214/3000
# 6/6 - 0s - loss: 0.0211
# Epoch 215/3000
# 6/6 - 0s - loss: 0.0210
# Epoch 216/3000
# 6/6 - 0s - loss: 0.0210
# Epoch 217/3000
# 6/6 - 0s - loss: 0.0209
# Epoch 218/3000
# 6/6 - 0s - loss: 0.0209
# Epoch 219/3000
# 6/6 - 0s - loss: 0.0208
# Epoch 220/3000
# 6/6 - 0s - loss: 0.0208
# Epoch 221/3000
# 6/6 - 0s - loss: 0.0208
# Epoch 222/3000
# 6/6 - 0s - loss: 0.0208
# Epoch 223/3000
# 6/6 - 0s - loss: 0.0207
# Epoch 224/3000
# 6/6 - 0s - loss: 0.0207
# Epoch 225/3000
# 6/6 - 0s - loss: 0.0206
# Epoch 226/3000
# 6/6 - 0s - loss: 0.0206
# Epoch 227/3000
# 6/6 - 0s - loss: 0.0205
# Epoch 228/3000
# 6/6 - 0s - loss: 0.0205
# Epoch 229/3000
# 6/6 - 0s - loss: 0.0205
# Epoch 230/3000
# 6/6 - 0s - loss: 0.0205
# Epoch 231/3000
# 6/6 - 0s - loss: 0.0204
# Epoch 232/3000
# 6/6 - 0s - loss: 0.0204
# Epoch 233/3000
# 6/6 - 0s - loss: 0.0203
# Epoch 234/3000
# 6/6 - 0s - loss: 0.0203
# Epoch 235/3000
# 6/6 - 0s - loss: 0.0203
# Epoch 236/3000
# 6/6 - 0s - loss: 0.0202
# Epoch 237/3000
# 6/6 - 0s - loss: 0.0202
# Epoch 238/3000
# 6/6 - 0s - loss: 0.0202
# Epoch 239/3000
# 6/6 - 0s - loss: 0.0201
# Epoch 240/3000
# 6/6 - 0s - loss: 0.0201
# Epoch 241/3000
# 6/6 - 0s - loss: 0.0200
# Epoch 242/3000
# 6/6 - 0s - loss: 0.0200
# Epoch 243/3000
# 6/6 - 0s - loss: 0.0200
# Epoch 244/3000
# 6/6 - 0s - loss: 0.0199
# Epoch 245/3000
# 6/6 - 0s - loss: 0.0199
# Epoch 246/3000
# 6/6 - 0s - loss: 0.0199
# Epoch 247/3000
# 6/6 - 0s - loss: 0.0198
# Epoch 248/3000
# 6/6 - 0s - loss: 0.0198
# Epoch 249/3000
# 6/6 - 0s - loss: 0.0198
# Epoch 250/3000
# 6/6 - 0s - loss: 0.0197
# Epoch 251/3000
# 6/6 - 0s - loss: 0.0197
# Epoch 252/3000
# 6/6 - 0s - loss: 0.0197
# Epoch 253/3000
# 6/6 - 0s - loss: 0.0196
# Epoch 254/3000
# 6/6 - 0s - loss: 0.0196
# Epoch 255/3000
# 6/6 - 0s - loss: 0.0196
# Epoch 256/3000
# 6/6 - 0s - loss: 0.0195
# Epoch 257/3000
# 6/6 - 0s - loss: 0.0195
# Epoch 258/3000
# 6/6 - 0s - loss: 0.0195
# Epoch 259/3000
# 6/6 - 0s - loss: 0.0195
# Epoch 260/3000
# 6/6 - 0s - loss: 0.0194
# Epoch 261/3000
# 6/6 - 0s - loss: 0.0194
# Epoch 262/3000
# 6/6 - 0s - loss: 0.0194
# Epoch 263/3000
# 6/6 - 0s - loss: 0.0194
# Epoch 264/3000
# 6/6 - 0s - loss: 0.0193
# Epoch 265/3000
# 6/6 - 0s - loss: 0.0193
# Epoch 266/3000
# 6/6 - 0s - loss: 0.0193
# Epoch 267/3000
# 6/6 - 0s - loss: 0.0193
# Epoch 268/3000
# 6/6 - 0s - loss: 0.0192
# Epoch 269/3000
# 6/6 - 0s - loss: 0.0192
# Epoch 270/3000
# 6/6 - 0s - loss: 0.0192
# Epoch 271/3000
# 6/6 - 0s - loss: 0.0191
# Epoch 272/3000
# 6/6 - 0s - loss: 0.0191
# Epoch 273/3000
# 6/6 - 0s - loss: 0.0190
# Epoch 274/3000
# 6/6 - 0s - loss: 0.0190
# Epoch 275/3000
# 6/6 - 0s - loss: 0.0190
# Epoch 276/3000
# 6/6 - 0s - loss: 0.0189
# Epoch 277/3000
# 6/6 - 0s - loss: 0.0189
# Epoch 278/3000
# 6/6 - 0s - loss: 0.0188
# Epoch 279/3000
# 6/6 - 0s - loss: 0.0188
# Epoch 280/3000
# 6/6 - 0s - loss: 0.0188
# Epoch 281/3000
# 6/6 - 0s - loss: 0.0188
# Epoch 282/3000
# 6/6 - 0s - loss: 0.0187
# Epoch 283/3000
# 6/6 - 0s - loss: 0.0187
# Epoch 284/3000
# 6/6 - 0s - loss: 0.0186
# Epoch 285/3000
# 6/6 - 0s - loss: 0.0187
# Epoch 286/3000
# 6/6 - 0s - loss: 0.0186
# Epoch 287/3000
# 6/6 - 0s - loss: 0.0186
# Epoch 288/3000
# 6/6 - 0s - loss: 0.0185
# Epoch 289/3000
# 6/6 - 0s - loss: 0.0185
# Epoch 290/3000
# 6/6 - 0s - loss: 0.0185
# Epoch 291/3000
# 6/6 - 0s - loss: 0.0185
# Epoch 292/3000
# 6/6 - 0s - loss: 0.0184
# Epoch 293/3000
# 6/6 - 0s - loss: 0.0184
# Epoch 294/3000
# 6/6 - 0s - loss: 0.0183
# Epoch 295/3000
# 6/6 - 0s - loss: 0.0184
# Epoch 296/3000
# 6/6 - 0s - loss: 0.0183
# Epoch 297/3000
# 6/6 - 0s - loss: 0.0183
# Epoch 298/3000
# 6/6 - 0s - loss: 0.0182
# Epoch 299/3000
# 6/6 - 0s - loss: 0.0182
# Epoch 300/3000
# 6/6 - 0s - loss: 0.0181
# Epoch 301/3000
# 6/6 - 0s - loss: 0.0181
# Epoch 302/3000
# 6/6 - 0s - loss: 0.0181
# Epoch 303/3000
# 6/6 - 0s - loss: 0.0180
# Epoch 304/3000
# 6/6 - 0s - loss: 0.0180
# Epoch 305/3000
# 6/6 - 0s - loss: 0.0179
# Epoch 306/3000
# 6/6 - 0s - loss: 0.0178
# Epoch 307/3000
# 6/6 - 0s - loss: 0.0178
# Epoch 308/3000
# 6/6 - 0s - loss: 0.0177
# Epoch 309/3000
# 6/6 - 0s - loss: 0.0177
# Epoch 310/3000
# 6/6 - 0s - loss: 0.0176
# Epoch 311/3000
# 6/6 - 0s - loss: 0.0176
# Epoch 312/3000
# 6/6 - 0s - loss: 0.0175
# Epoch 313/3000
# 6/6 - 0s - loss: 0.0175
# Epoch 314/3000
# 6/6 - 0s - loss: 0.0174
# Epoch 315/3000
# 6/6 - 0s - loss: 0.0173
# Epoch 316/3000
# 6/6 - 0s - loss: 0.0171
# Epoch 317/3000
# 6/6 - 0s - loss: 0.0170
# Epoch 318/3000
# 6/6 - 0s - loss: 0.0168
# Epoch 319/3000
# 6/6 - 0s - loss: 0.0167
# Epoch 320/3000
# 6/6 - 0s - loss: 0.0166
# Epoch 321/3000
# 6/6 - 0s - loss: 0.0166
# Epoch 322/3000
# 6/6 - 0s - loss: 0.0165
# Epoch 323/3000
# 6/6 - 0s - loss: 0.0165
# Epoch 324/3000
# 6/6 - 0s - loss: 0.0164
# Epoch 325/3000
# 6/6 - 0s - loss: 0.0164
# Epoch 326/3000
# 6/6 - 0s - loss: 0.0164
# Epoch 327/3000
# 6/6 - 0s - loss: 0.0163
# Epoch 328/3000
# 6/6 - 0s - loss: 0.0162
# Epoch 329/3000
# 6/6 - 0s - loss: 0.0162
# Epoch 330/3000
# 6/6 - 0s - loss: 0.0162
# Epoch 331/3000
# 6/6 - 0s - loss: 0.0161
# Epoch 332/3000
# 6/6 - 0s - loss: 0.0161
# Epoch 333/3000
# 6/6 - 0s - loss: 0.0160
# Epoch 334/3000
# 6/6 - 0s - loss: 0.0160
# Epoch 335/3000
# 6/6 - 0s - loss: 0.0159
# Epoch 336/3000
# 6/6 - 0s - loss: 0.0159
# Epoch 337/3000
# 6/6 - 0s - loss: 0.0158
# Epoch 338/3000
# 6/6 - 0s - loss: 0.0158
# Epoch 339/3000
# 6/6 - 0s - loss: 0.0157
# Epoch 340/3000
# 6/6 - 0s - loss: 0.0157
# Epoch 341/3000
# 6/6 - 0s - loss: 0.0157
# Epoch 342/3000
# 6/6 - 0s - loss: 0.0156
# Epoch 343/3000
# 6/6 - 0s - loss: 0.0156
# Epoch 344/3000
# 6/6 - 0s - loss: 0.0155
# Epoch 345/3000
# 6/6 - 0s - loss: 0.0155
# Epoch 346/3000
# 6/6 - 0s - loss: 0.0154
# Epoch 347/3000
# 6/6 - 0s - loss: 0.0155
# Epoch 348/3000
# 6/6 - 0s - loss: 0.0153
# Epoch 349/3000
# 6/6 - 0s - loss: 0.0154
# Epoch 350/3000
# 6/6 - 0s - loss: 0.0152
# Epoch 351/3000
# 6/6 - 0s - loss: 0.0153
# Epoch 352/3000
# 6/6 - 0s - loss: 0.0152
# Epoch 353/3000
# 6/6 - 0s - loss: 0.0152
# Epoch 354/3000
# 6/6 - 0s - loss: 0.0151
# Epoch 355/3000
# 6/6 - 0s - loss: 0.0152
# Epoch 356/3000
# 6/6 - 0s - loss: 0.0150
# Epoch 357/3000
# 6/6 - 0s - loss: 0.0151
# Epoch 358/3000
# 6/6 - 0s - loss: 0.0149
# Epoch 359/3000
# 6/6 - 0s - loss: 0.0151
# Epoch 360/3000
# 6/6 - 0s - loss: 0.0149
# Epoch 361/3000
# 6/6 - 0s - loss: 0.0150
# Epoch 362/3000
# 6/6 - 0s - loss: 0.0148
# Epoch 363/3000
# 6/6 - 0s - loss: 0.0150
# Epoch 364/3000
# 6/6 - 0s - loss: 0.0148
# Epoch 365/3000
# 6/6 - 0s - loss: 0.0149
# Epoch 366/3000
# 6/6 - 0s - loss: 0.0147
# Epoch 367/3000
# 6/6 - 0s - loss: 0.0148
# Epoch 368/3000
# 6/6 - 0s - loss: 0.0146
# Epoch 369/3000
# 6/6 - 0s - loss: 0.0147
# Epoch 370/3000
# 6/6 - 0s - loss: 0.0145
# Epoch 371/3000
# 6/6 - 0s - loss: 0.0146
# Epoch 372/3000
# 6/6 - 0s - loss: 0.0144
# Epoch 373/3000
# 6/6 - 0s - loss: 0.0144
# Epoch 374/3000
# 6/6 - 0s - loss: 0.0143
# Epoch 375/3000
# 6/6 - 0s - loss: 0.0143
# Epoch 376/3000
# 6/6 - 0s - loss: 0.0142
# Epoch 377/3000
# 6/6 - 0s - loss: 0.0141
# Epoch 378/3000
# 6/6 - 0s - loss: 0.0142
# Epoch 379/3000
# 6/6 - 0s - loss: 0.0140
# Epoch 380/3000
# 6/6 - 0s - loss: 0.0141
# Epoch 381/3000
# 6/6 - 0s - loss: 0.0139
# Epoch 382/3000
# 6/6 - 0s - loss: 0.0140
# Epoch 383/3000
# 6/6 - 0s - loss: 0.0138
# Epoch 384/3000
# 6/6 - 0s - loss: 0.0139
# Epoch 385/3000
# 6/6 - 0s - loss: 0.0137
# Epoch 386/3000
# 6/6 - 0s - loss: 0.0138
# Epoch 387/3000
# 6/6 - 0s - loss: 0.0136
# Epoch 388/3000
# 6/6 - 0s - loss: 0.0137
# Epoch 389/3000
# 6/6 - 0s - loss: 0.0136
# Epoch 390/3000
# 6/6 - 0s - loss: 0.0137
# Epoch 391/3000
# 6/6 - 0s - loss: 0.0135
# Epoch 392/3000
# 6/6 - 0s - loss: 0.0136
# Epoch 393/3000
# 6/6 - 0s - loss: 0.0135
# Epoch 394/3000
# 6/6 - 0s - loss: 0.0136
# Epoch 395/3000
# 6/6 - 0s - loss: 0.0134
# Epoch 396/3000
# 6/6 - 0s - loss: 0.0135
# Epoch 397/3000
# 6/6 - 0s - loss: 0.0134
# Epoch 398/3000
# 6/6 - 0s - loss: 0.0134
# Epoch 399/3000
# 6/6 - 0s - loss: 0.0133
# Epoch 400/3000
# 6/6 - 0s - loss: 0.0133
# Epoch 401/3000
# 6/6 - 0s - loss: 0.0133
# Epoch 402/3000
# 6/6 - 0s - loss: 0.0132
# Epoch 403/3000
# 6/6 - 0s - loss: 0.0132
# Epoch 404/3000
# 6/6 - 0s - loss: 0.0131
# Epoch 405/3000
# 6/6 - 0s - loss: 0.0131
# Epoch 406/3000
# 6/6 - 0s - loss: 0.0129
# Epoch 407/3000
# 6/6 - 0s - loss: 0.0130
# Epoch 408/3000
# 6/6 - 0s - loss: 0.0128
# Epoch 409/3000
# 6/6 - 0s - loss: 0.0129
# Epoch 410/3000
# 6/6 - 0s - loss: 0.0127
# Epoch 411/3000
# 6/6 - 0s - loss: 0.0128
# Epoch 412/3000
# 6/6 - 0s - loss: 0.0126
# Epoch 413/3000
# 6/6 - 0s - loss: 0.0128
# Epoch 414/3000
# 6/6 - 0s - loss: 0.0125
# Epoch 415/3000
# 6/6 - 0s - loss: 0.0126
# Epoch 416/3000
# 6/6 - 0s - loss: 0.0124
# Epoch 417/3000
# 6/6 - 0s - loss: 0.0126
# Epoch 418/3000
# 6/6 - 0s - loss: 0.0124
# Epoch 419/3000
# 6/6 - 0s - loss: 0.0125
# Epoch 420/3000
# 6/6 - 0s - loss: 0.0123
# Epoch 421/3000
# 6/6 - 0s - loss: 0.0123
# Epoch 422/3000
# 6/6 - 0s - loss: 0.0122
# Epoch 423/3000
# 6/6 - 0s - loss: 0.0122
# Epoch 424/3000
# 6/6 - 0s - loss: 0.0122
# Epoch 425/3000
# 6/6 - 0s - loss: 0.0121
# Epoch 426/3000
# 6/6 - 0s - loss: 0.0121
# Epoch 427/3000
# 6/6 - 0s - loss: 0.0121
# Epoch 428/3000
# 6/6 - 0s - loss: 0.0120
# Epoch 429/3000
# 6/6 - 0s - loss: 0.0120
# Epoch 430/3000
# 6/6 - 0s - loss: 0.0120
# Epoch 431/3000
# 6/6 - 0s - loss: 0.0119
# Epoch 432/3000
# 6/6 - 0s - loss: 0.0119
# Epoch 433/3000
# 6/6 - 0s - loss: 0.0118
# Epoch 434/3000
# 6/6 - 0s - loss: 0.0118
# Epoch 435/3000
# 6/6 - 0s - loss: 0.0118
# Epoch 436/3000
# 6/6 - 0s - loss: 0.0117
# Epoch 437/3000
# 6/6 - 0s - loss: 0.0116
# Epoch 438/3000
# 6/6 - 0s - loss: 0.0116
# Epoch 439/3000
# 6/6 - 0s - loss: 0.0116
# Epoch 440/3000
# 6/6 - 0s - loss: 0.0116
# Epoch 441/3000
# 6/6 - 0s - loss: 0.0115
# Epoch 442/3000
# 6/6 - 0s - loss: 0.0115
# Epoch 443/3000
# 6/6 - 0s - loss: 0.0114
# Epoch 444/3000
# 6/6 - 0s - loss: 0.0114
# Epoch 445/3000
# 6/6 - 0s - loss: 0.0113
# Epoch 446/3000
# 6/6 - 0s - loss: 0.0113
# Epoch 447/3000
# 6/6 - 0s - loss: 0.0113
# Epoch 448/3000
# 6/6 - 0s - loss: 0.0112
# Epoch 449/3000
# 6/6 - 0s - loss: 0.0112
# Epoch 450/3000
# 6/6 - 0s - loss: 0.0112
# Epoch 451/3000
# 6/6 - 0s - loss: 0.0111
# Epoch 452/3000
# 6/6 - 0s - loss: 0.0111
# Epoch 453/3000
# 6/6 - 0s - loss: 0.0111
# Epoch 454/3000
# 6/6 - 0s - loss: 0.0110
# Epoch 455/3000
# 6/6 - 0s - loss: 0.0109
# Epoch 456/3000
# 6/6 - 0s - loss: 0.0109
# Epoch 457/3000
# 6/6 - 0s - loss: 0.0109
# Epoch 458/3000
# 6/6 - 0s - loss: 0.0108
# Epoch 459/3000
# 6/6 - 0s - loss: 0.0108
# Epoch 460/3000
# 6/6 - 0s - loss: 0.0107
# Epoch 461/3000
# 6/6 - 0s - loss: 0.0107
# Epoch 462/3000
# 6/6 - 0s - loss: 0.0107
# Epoch 463/3000
# 6/6 - 0s - loss: 0.0106
# Epoch 464/3000
# 6/6 - 0s - loss: 0.0105
# Epoch 465/3000
# 6/6 - 0s - loss: 0.0106
# Epoch 466/3000
# 6/6 - 0s - loss: 0.0105
# Epoch 467/3000
# 6/6 - 0s - loss: 0.0104
# Epoch 468/3000
# 6/6 - 0s - loss: 0.0104
# Epoch 469/3000
# 6/6 - 0s - loss: 0.0103
# Epoch 470/3000
# 6/6 - 0s - loss: 0.0103
# Epoch 471/3000
# 6/6 - 0s - loss: 0.0103
# Epoch 472/3000
# 6/6 - 0s - loss: 0.0102
# Epoch 473/3000
# 6/6 - 0s - loss: 0.0102
# Epoch 474/3000
# 6/6 - 0s - loss: 0.0102
# Epoch 475/3000
# 6/6 - 0s - loss: 0.0101
# Epoch 476/3000
# 6/6 - 0s - loss: 0.0101
# Epoch 477/3000
# 6/6 - 0s - loss: 0.0100
# Epoch 478/3000
# 6/6 - 0s - loss: 0.0099
# Epoch 479/3000
# 6/6 - 0s - loss: 0.0099
# Epoch 480/3000
# 6/6 - 0s - loss: 0.0098
# Epoch 481/3000
# 6/6 - 0s - loss: 0.0099
# Epoch 482/3000
# 6/6 - 0s - loss: 0.0098
# Epoch 483/3000
# 6/6 - 0s - loss: 0.0097
# Epoch 484/3000
# 6/6 - 0s - loss: 0.0098
# Epoch 485/3000
# 6/6 - 0s - loss: 0.0097
# Epoch 486/3000
# 6/6 - 0s - loss: 0.0097
# Epoch 487/3000
# 6/6 - 0s - loss: 0.0096
# Epoch 488/3000
# 6/6 - 0s - loss: 0.0095
# Epoch 489/3000
# 6/6 - 0s - loss: 0.0095
# Epoch 490/3000
# 6/6 - 0s - loss: 0.0094
# Epoch 491/3000
# 6/6 - 0s - loss: 0.0094
# Epoch 492/3000
# 6/6 - 0s - loss: 0.0094
# Epoch 493/3000
# 6/6 - 0s - loss: 0.0093
# Epoch 494/3000
# 6/6 - 0s - loss: 0.0094
# Epoch 495/3000
# 6/6 - 0s - loss: 0.0093
# Epoch 496/3000
# 6/6 - 0s - loss: 0.0092
# Epoch 497/3000
# 6/6 - 0s - loss: 0.0092
# Epoch 498/3000
# 6/6 - 0s - loss: 0.0091
# Epoch 499/3000
# 6/6 - 0s - loss: 0.0091
# Epoch 500/3000
# 6/6 - 0s - loss: 0.0091
# Epoch 501/3000
# 6/6 - 0s - loss: 0.0090
# Epoch 502/3000
# 6/6 - 0s - loss: 0.0089
# Epoch 503/3000
# 6/6 - 0s - loss: 0.0091
# Epoch 504/3000
# 6/6 - 0s - loss: 0.0089
# Epoch 505/3000
# 6/6 - 0s - loss: 0.0088
# Epoch 506/3000
# 6/6 - 0s - loss: 0.0089
# Epoch 507/3000
# 6/6 - 0s - loss: 0.0087
# Epoch 508/3000
# 6/6 - 0s - loss: 0.0087
# Epoch 509/3000
# 6/6 - 0s - loss: 0.0088
# Epoch 510/3000
# 6/6 - 0s - loss: 0.0087
# Epoch 511/3000
# 6/6 - 0s - loss: 0.0085
# Epoch 512/3000
# 6/6 - 0s - loss: 0.0087
# Epoch 513/3000
# 6/6 - 0s - loss: 0.0086
# Epoch 514/3000
# 6/6 - 0s - loss: 0.0084
# Epoch 515/3000
# 6/6 - 0s - loss: 0.0085
# Epoch 516/3000
# 6/6 - 0s - loss: 0.0084
# Epoch 517/3000
# 6/6 - 0s - loss: 0.0084
# Epoch 518/3000
# 6/6 - 0s - loss: 0.0084
# Epoch 519/3000
# 6/6 - 0s - loss: 0.0083
# Epoch 520/3000
# 6/6 - 0s - loss: 0.0082
# Epoch 521/3000
# 6/6 - 0s - loss: 0.0083
# Epoch 522/3000
# 6/6 - 0s - loss: 0.0082
# Epoch 523/3000
# 6/6 - 0s - loss: 0.0081
# Epoch 524/3000
# 6/6 - 0s - loss: 0.0081
# Epoch 525/3000
# 6/6 - 0s - loss: 0.0081
# Epoch 526/3000
# 6/6 - 0s - loss: 0.0081
# Epoch 527/3000
# 6/6 - 0s - loss: 0.0080
# Epoch 528/3000
# 6/6 - 0s - loss: 0.0080
# Epoch 529/3000
# 6/6 - 0s - loss: 0.0079
# Epoch 530/3000
# 6/6 - 0s - loss: 0.0080
# Epoch 531/3000
# 6/6 - 0s - loss: 0.0079
# Epoch 532/3000
# 6/6 - 0s - loss: 0.0078
# Epoch 533/3000
# 6/6 - 0s - loss: 0.0080
# Epoch 534/3000
# 6/6 - 0s - loss: 0.0078
# Epoch 535/3000
# 6/6 - 0s - loss: 0.0077
# Epoch 536/3000
# 6/6 - 0s - loss: 0.0078
# Epoch 537/3000
# 6/6 - 0s - loss: 0.0077
# Epoch 538/3000
# 6/6 - 0s - loss: 0.0076
# Epoch 539/3000
# 6/6 - 0s - loss: 0.0077
# Epoch 540/3000
# 6/6 - 0s - loss: 0.0076
# Epoch 541/3000
# 6/6 - 0s - loss: 0.0074
# Epoch 542/3000
# 6/6 - 0s - loss: 0.0076
# Epoch 543/3000
# 6/6 - 0s - loss: 0.0075
# Epoch 544/3000
# 6/6 - 0s - loss: 0.0073
# Epoch 545/3000
# 6/6 - 0s - loss: 0.0074
# Epoch 546/3000
# 6/6 - 0s - loss: 0.0075
# Epoch 547/3000
# 6/6 - 0s - loss: 0.0073
# Epoch 548/3000
# 6/6 - 0s - loss: 0.0072
# Epoch 549/3000
# 6/6 - 0s - loss: 0.0074
# Epoch 550/3000
# 6/6 - 0s - loss: 0.0072
# Epoch 551/3000
# 6/6 - 0s - loss: 0.0071
# Epoch 552/3000
# 6/6 - 0s - loss: 0.0073
# Epoch 553/3000
# 6/6 - 0s - loss: 0.0072
# Epoch 554/3000
# 6/6 - 0s - loss: 0.0070
# Epoch 555/3000
# 6/6 - 0s - loss: 0.0071
# Epoch 556/3000
# 6/6 - 0s - loss: 0.0072
# Epoch 557/3000
# 6/6 - 0s - loss: 0.0069
# Epoch 558/3000
# 6/6 - 0s - loss: 0.0069
# Epoch 559/3000
# 6/6 - 0s - loss: 0.0071
# Epoch 560/3000
# 6/6 - 0s - loss: 0.0069
# Epoch 561/3000
# 6/6 - 0s - loss: 0.0068
# Epoch 562/3000
# 6/6 - 0s - loss: 0.0070
# Epoch 563/3000
# 6/6 - 0s - loss: 0.0068
# Epoch 564/3000
# 6/6 - 0s - loss: 0.0067
# Epoch 565/3000
# 6/6 - 0s - loss: 0.0070
# Epoch 566/3000
# 6/6 - 0s - loss: 0.0068
# Epoch 567/3000
# 6/6 - 0s - loss: 0.0066
# Epoch 568/3000
# 6/6 - 0s - loss: 0.0068
# Epoch 569/3000
# 6/6 - 0s - loss: 0.0068
# Epoch 570/3000
# 6/6 - 0s - loss: 0.0065
# Epoch 571/3000
# 6/6 - 0s - loss: 0.0066
# Epoch 572/3000
# 6/6 - 0s - loss: 0.0066
# Epoch 573/3000
# 6/6 - 0s - loss: 0.0064
# Epoch 574/3000
# 6/6 - 0s - loss: 0.0066
# Epoch 575/3000
# 6/6 - 0s - loss: 0.0065
# Epoch 576/3000
# 6/6 - 0s - loss: 0.0063
# Epoch 577/3000
# 6/6 - 0s - loss: 0.0066
# Epoch 578/3000
# 6/6 - 0s - loss: 0.0065
# Epoch 579/3000
# 6/6 - 0s - loss: 0.0063
# Epoch 580/3000
# 6/6 - 0s - loss: 0.0066
# Epoch 581/3000
# 6/6 - 0s - loss: 0.0065
# Epoch 582/3000
# 6/6 - 0s - loss: 0.0062
# Epoch 583/3000
# 6/6 - 0s - loss: 0.0065
# Epoch 584/3000
# 6/6 - 0s - loss: 0.0064
# Epoch 585/3000
# 6/6 - 0s - loss: 0.0061
# Epoch 586/3000
# 6/6 - 0s - loss: 0.0063
# Epoch 587/3000
# 6/6 - 0s - loss: 0.0064
# Epoch 588/3000
# 6/6 - 0s - loss: 0.0060
# Epoch 589/3000
# 6/6 - 0s - loss: 0.0061
# Epoch 590/3000
# 6/6 - 0s - loss: 0.0062
# Epoch 591/3000
# 6/6 - 0s - loss: 0.0059
# Epoch 592/3000
# 6/6 - 0s - loss: 0.0060
# Epoch 593/3000
# 6/6 - 0s - loss: 0.0062
# Epoch 594/3000
# 6/6 - 0s - loss: 0.0059
# Epoch 595/3000
# 6/6 - 0s - loss: 0.0058
# Epoch 596/3000
# 6/6 - 0s - loss: 0.0061
# Epoch 597/3000
# 6/6 - 0s - loss: 0.0058
# Epoch 598/3000
# 6/6 - 0s - loss: 0.0057
# Epoch 599/3000
# 6/6 - 0s - loss: 0.0059
# Epoch 600/3000
# 6/6 - 0s - loss: 0.0058
# Epoch 601/3000
# 6/6 - 0s - loss: 0.0056
# Epoch 602/3000
# 6/6 - 0s - loss: 0.0057
# Epoch 603/3000
# 6/6 - 0s - loss: 0.0058
# Epoch 604/3000
# 6/6 - 0s - loss: 0.0056
# Epoch 605/3000
# 6/6 - 0s - loss: 0.0056
# Epoch 606/3000
# 6/6 - 0s - loss: 0.0058
# Epoch 607/3000
# 6/6 - 0s - loss: 0.0055
# Epoch 608/3000
# 6/6 - 0s - loss: 0.0054
# Epoch 609/3000
# 6/6 - 0s - loss: 0.0057
# Epoch 610/3000
# 6/6 - 0s - loss: 0.0055
# Epoch 611/3000
# 6/6 - 0s - loss: 0.0054
# Epoch 612/3000
# 6/6 - 0s - loss: 0.0056
# Epoch 613/3000
# 6/6 - 0s - loss: 0.0056
# Epoch 614/3000
# 6/6 - 0s - loss: 0.0053
# Epoch 615/3000
# 6/6 - 0s - loss: 0.0053
# Epoch 616/3000
# 6/6 - 0s - loss: 0.0055
# Epoch 617/3000
# 6/6 - 0s - loss: 0.0053
# Epoch 618/3000
# 6/6 - 0s - loss: 0.0052
# Epoch 619/3000
# 6/6 - 0s - loss: 0.0054
# Epoch 620/3000
# 6/6 - 0s - loss: 0.0052
# Epoch 621/3000
# 6/6 - 0s - loss: 0.0051
# Epoch 622/3000
# 6/6 - 0s - loss: 0.0052
# Epoch 623/3000
# 6/6 - 0s - loss: 0.0052
# Epoch 624/3000
# 6/6 - 0s - loss: 0.0051
# Epoch 625/3000
# 6/6 - 0s - loss: 0.0050
# Epoch 626/3000
# 6/6 - 0s - loss: 0.0052
# Epoch 627/3000
# 6/6 - 0s - loss: 0.0051
# Epoch 628/3000
# 6/6 - 0s - loss: 0.0050
# Epoch 629/3000
# 6/6 - 0s - loss: 0.0051
# Epoch 630/3000
# 6/6 - 0s - loss: 0.0052
# Epoch 631/3000
# 6/6 - 0s - loss: 0.0050
# Epoch 632/3000
# 6/6 - 0s - loss: 0.0049
# Epoch 633/3000
# 6/6 - 0s - loss: 0.0053
# Epoch 634/3000
# 6/6 - 0s - loss: 0.0050
# Epoch 635/3000
# 6/6 - 0s - loss: 0.0048
# Epoch 636/3000
# 6/6 - 0s - loss: 0.0051
# Epoch 637/3000
# 6/6 - 0s - loss: 0.0051
# Epoch 638/3000
# 6/6 - 0s - loss: 0.0048
# Epoch 639/3000
# 6/6 - 0s - loss: 0.0049
# Epoch 640/3000
# 6/6 - 0s - loss: 0.0051
# Epoch 641/3000
# 6/6 - 0s - loss: 0.0048
# Epoch 642/3000
# 6/6 - 0s - loss: 0.0047
# Epoch 643/3000
# 6/6 - 0s - loss: 0.0050
# Epoch 644/3000
# 6/6 - 0s - loss: 0.0049
# Epoch 645/3000
# 6/6 - 0s - loss: 0.0047
# Epoch 646/3000
# 6/6 - 0s - loss: 0.0048
# Epoch
3000
# 6/6 - 0s - loss: 0.0018
# Epoch 2794/3000
# 6/6 - 0s - loss: 0.0035
# Epoch 2795/3000
# 6/6 - 0s - loss: 0.0021
# Epoch 2796/3000
# 6/6 - 0s - loss: 0.0032
# Epoch 2797/3000
# 6/6 - 0s - loss: 0.0020
# Epoch 2798/3000
# 6/6 - 0s - loss: 0.0036
# Epoch 2799/3000
# 6/6 - 0s - loss: 0.0022
# Epoch 2800/3000
# 6/6 - 0s - loss: 0.0028
# Epoch 2801/3000
# 6/6 - 0s - loss: 0.0018
# Epoch 2802/3000
# 6/6 - 0s - loss: 0.0027
# Epoch 2803/3000
# 6/6 - 0s - loss: 0.0018
# Epoch 2804/3000
# 6/6 - 0s - loss: 0.0019
# Epoch 2805/3000
# 6/6 - 0s - loss: 0.0014
# Epoch 2806/3000
# 6/6 - 0s - loss: 0.0019
# Epoch 2807/3000
# 6/6 - 0s - loss: 0.0014
# Epoch 2808/3000
# 6/6 - 0s - loss: 0.0014
# Epoch 2809/3000
# 6/6 - 0s - loss: 0.0013
# Epoch 2810/3000
# 6/6 - 0s - loss: 0.0015
# Epoch 2811/3000
# 6/6 - 0s - loss: 0.0013
# Epoch 2812/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2813/3000
# 6/6 - 0s - loss: 0.0013
# Epoch 2814/3000
# 6/6 - 0s - loss: 0.0012
# Epoch 2815/3000
# 6/6 - 0s - loss: 0.0012
# Epoch 2816/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2817/3000
# 6/6 - 0s - loss: 0.0012
# Epoch 2818/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2819/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2820/3000
# 6/6 - 0s - loss: 9.6740e-04
# Epoch 2821/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2822/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2823/3000
# 6/6 - 0s - loss: 9.9766e-04
# Epoch 2824/3000
# 6/6 - 0s - loss: 9.7512e-04
# Epoch 2825/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2826/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2827/3000
# 6/6 - 0s - loss: 9.7357e-04
# Epoch 2828/3000
# 6/6 - 0s - loss: 9.9058e-04
# Epoch 2829/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2830/3000
# 6/6 - 0s - loss: 9.8836e-04
# Epoch 2831/3000
# 6/6 - 0s - loss: 9.7107e-04
# Epoch 2832/3000
# 6/6 - 0s - loss: 9.8634e-04
# Epoch 2833/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2834/3000
# 6/6 - 0s - loss: 9.7740e-04
# Epoch 2835/3000
# 6/6 - 0s - loss: 9.5447e-04
# Epoch 2836/3000
# 6/6 - 0s - loss: 9.6968e-04
# Epoch 2837/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2838/3000
# 6/6 - 0s - loss: 9.6122e-04
# Epoch 2839/3000
# 6/6 - 0s - loss: 9.4303e-04
# Epoch 2840/3000
# 6/6 - 0s - loss: 9.5825e-04
# Epoch 2841/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2842/3000
# 6/6 - 0s - loss: 9.5049e-04
# Epoch 2843/3000
# 6/6 - 0s - loss: 9.4226e-04
# Epoch 2844/3000
# 6/6 - 0s - loss: 9.4126e-04
# Epoch 2845/3000
# 6/6 - 0s - loss: 9.8816e-04
# Epoch 2846/3000
# 6/6 - 0s - loss: 9.4989e-04
# Epoch 2847/3000
# 6/6 - 0s - loss: 9.4516e-04
# Epoch 2848/3000
# 6/6 - 0s - loss: 9.2615e-04
# Epoch 2849/3000
# 6/6 - 0s - loss: 9.7795e-04
# Epoch 2850/3000
# 6/6 - 0s - loss: 9.5679e-04
# Epoch 2851/3000
# 6/6 - 0s - loss: 9.4862e-04
# Epoch 2852/3000
# 6/6 - 0s - loss: 9.2494e-04
# Epoch 2853/3000
# 6/6 - 0s - loss: 9.6907e-04
# Epoch 2854/3000
# 6/6 - 0s - loss: 9.7589e-04
# Epoch 2855/3000
# 6/6 - 0s - loss: 9.5754e-04
# Epoch 2856/3000
# 6/6 - 0s - loss: 9.2770e-04
# Epoch 2857/3000
# 6/6 - 0s - loss: 9.5794e-04
# Epoch 2858/3000
# 6/6 - 0s - loss: 9.9869e-04
# Epoch 2859/3000
# 6/6 - 0s - loss: 9.6245e-04
# Epoch 2860/3000
# 6/6 - 0s - loss: 9.6087e-04
# Epoch 2861/3000
# 6/6 - 0s - loss: 9.3718e-04
# Epoch 2862/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2863/3000
# 6/6 - 0s - loss: 9.9227e-04
# Epoch 2864/3000
# 6/6 - 0s - loss: 9.9060e-04
# Epoch 2865/3000
# 6/6 - 0s - loss: 9.4934e-04
# Epoch 2866/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2867/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2868/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2869/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2870/3000
# 6/6 - 0s - loss: 9.7895e-04
# Epoch 2871/3000
# 6/6 - 0s - loss: 0.0012
# Epoch 2872/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2873/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2874/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2875/3000
# 6/6 - 0s - loss: 0.0012
# Epoch 2876/3000
# 6/6 - 0s - loss: 0.0015
# Epoch 2877/3000
# 6/6 - 0s - loss: 0.0012
# Epoch 2878/3000
# 6/6 - 0s - loss: 0.0016
# Epoch 2879/3000
# 6/6 - 0s - loss: 0.0013
# Epoch 2880/3000
# 6/6 - 0s - loss: 0.0019
# Epoch 2881/3000
# 6/6 - 0s - loss: 0.0018
# Epoch 2882/3000
# 6/6 - 0s - loss: 0.0017
# Epoch 2883/3000
# 6/6 - 0s - loss: 0.0020
# Epoch 2884/3000
# 6/6 - 0s - loss: 0.0017
# Epoch 2885/3000
# 6/6 - 0s - loss: 0.0028
# Epoch 2886/3000
# 6/6 - 0s - loss: 0.0018
# Epoch 2887/3000
# 6/6 - 0s - loss: 0.0028
# Epoch 2888/3000
# 6/6 - 0s - loss: 0.0017
# Epoch 2889/3000
# 6/6 - 0s - loss: 0.0033
# Epoch 2890/3000
# 6/6 - 0s - loss: 0.0022
# Epoch 2891/3000
# 6/6 - 0s - loss: 0.0028
# Epoch 2892/3000
# 6/6 - 0s - loss: 0.0020
# Epoch 2893/3000
# 6/6 - 0s - loss: 0.0027
# Epoch 2894/3000
# 6/6 - 0s - loss: 0.0024
# Epoch 2895/3000
# 6/6 - 0s - loss: 0.0021
# Epoch 2896/3000
# 6/6 - 0s - loss: 0.0018
# Epoch 2897/3000
# 6/6 - 0s - loss: 0.0019
# Epoch 2898/3000
# 6/6 - 0s - loss: 0.0018
# Epoch 2899/3000
# 6/6 - 0s - loss: 0.0015
# Epoch 2900/3000
# 6/6 - 0s - loss: 0.0013
# Epoch 2901/3000
# 6/6 - 0s - loss: 0.0015
# Epoch 2902/3000
# 6/6 - 0s - loss: 0.0013
# Epoch 2903/3000
# 6/6 - 0s - loss: 0.0012
# Epoch 2904/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2905/3000
# 6/6 - 0s - loss: 0.0013
# Epoch 2906/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2907/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2908/3000
# 6/6 - 0s - loss: 9.9273e-04
# Epoch 2909/3000
# 6/6 - 0s - loss: 0.0012
# Epoch 2910/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2911/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2912/3000
# 6/6 - 0s - loss: 9.7824e-04
# Epoch 2913/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2914/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2915/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2916/3000
# 6/6 - 0s - loss: 9.7219e-04
# Epoch 2917/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2918/3000
# 6/6 - 0s - loss: 9.9862e-04
# Epoch 2919/3000
# 6/6 - 0s - loss: 9.7916e-04
# Epoch 2920/3000
# 6/6 - 0s - loss: 9.6487e-04
# Epoch 2921/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2922/3000
# 6/6 - 0s - loss: 9.7650e-04
# Epoch 2923/3000
# 6/6 - 0s - loss: 9.5226e-04
# Epoch 2924/3000
# 6/6 - 0s - loss: 9.4883e-04
# Epoch 2925/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2926/3000
# 6/6 - 0s - loss: 9.5626e-04
# Epoch 2927/3000
# 6/6 - 0s - loss: 9.3815e-04
# Epoch 2928/3000
# 6/6 - 0s - loss: 9.3298e-04
# Epoch 2929/3000
# 6/6 - 0s - loss: 9.9962e-04
# Epoch 2930/3000
# 6/6 - 0s - loss: 9.4391e-04
# Epoch 2931/3000
# 6/6 - 0s - loss: 9.2604e-04
# Epoch 2932/3000
# 6/6 - 0s - loss: 9.2065e-04
# Epoch 2933/3000
# 6/6 - 0s - loss: 9.6603e-04
# Epoch 2934/3000
# 6/6 - 0s - loss: 9.3427e-04
# Epoch 2935/3000
# 6/6 - 0s - loss: 9.2323e-04
# Epoch 2936/3000
# 6/6 - 0s - loss: 9.1306e-04
# Epoch 2937/3000
# 6/6 - 0s - loss: 9.6340e-04
# Epoch 2938/3000
# 6/6 - 0s - loss: 9.3713e-04
# Epoch 2939/3000
# 6/6 - 0s - loss: 9.2381e-04
# Epoch 2940/3000
# 6/6 - 0s - loss: 9.0789e-04
# Epoch 2941/3000
# 6/6 - 0s - loss: 9.4169e-04
# Epoch 2942/3000
# 6/6 - 0s - loss: 9.3769e-04
# Epoch 2943/3000
# 6/6 - 0s - loss: 9.2467e-04
# Epoch 2944/3000
# 6/6 - 0s - loss: 9.0439e-04
# Epoch 2945/3000
# 6/6 - 0s - loss: 9.2489e-04
# Epoch 2946/3000
# 6/6 - 0s - loss: 9.4073e-04
# Epoch 2947/3000
# 6/6 - 0s - loss: 9.2769e-04
# Epoch 2948/3000
# 6/6 - 0s - loss: 9.0793e-04
# Epoch 2949/3000
# 6/6 - 0s - loss: 9.0966e-04
# Epoch 2950/3000
# 6/6 - 0s - loss: 9.4456e-04
# Epoch 2951/3000
# 6/6 - 0s - loss: 9.3457e-04
# Epoch 2952/3000
# 6/6 - 0s - loss: 9.1715e-04
# Epoch 2953/3000
# 6/6 - 0s - loss: 9.0175e-04
# Epoch 2954/3000
# 6/6 - 0s - loss: 9.2633e-04
# Epoch 2955/3000
# 6/6 - 0s - loss: 9.4722e-04
# Epoch 2956/3000
# 6/6 - 0s - loss: 9.2136e-04
# Epoch 2957/3000
# 6/6 - 0s - loss: 9.1263e-04
# Epoch 2958/3000
# 6/6 - 0s - loss: 9.0228e-04
# Epoch 2959/3000
# 6/6 - 0s - loss: 9.5487e-04
# Epoch 2960/3000
# 6/6 - 0s - loss: 9.3590e-04
# Epoch 2961/3000
# 6/6 - 0s - loss: 9.3228e-04
# Epoch 2962/3000
# 6/6 - 0s - loss: 8.9882e-04
# Epoch 2963/3000
# 6/6 - 0s - loss: 9.3922e-04
# Epoch 2964/3000
# 6/6 - 0s - loss: 9.7531e-04
# Epoch 2965/3000
# 6/6 - 0s - loss: 9.4392e-04
# Epoch 2966/3000
# 6/6 - 0s - loss: 9.3883e-04
# Epoch 2967/3000
# 6/6 - 0s - loss: 9.0680e-04
# Epoch 2968/3000
# 6/6 - 0s - loss: 0.0010
# Epoch 2969/3000
# 6/6 - 0s - loss: 9.9951e-04
# Epoch 2970/3000
# 6/6 - 0s - loss: 9.8114e-04
# Epoch 2971/3000
# 6/6 - 0s - loss: 9.7312e-04
# Epoch 2972/3000
# 6/6 - 0s - loss: 9.6810e-04
# Epoch 2973/3000
# 6/6 - 0s - loss: 0.0012
# Epoch 2974/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2975/3000
# 6/6 - 0s - loss: 0.0012
# Epoch 2976/3000
# 6/6 - 0s - loss: 0.0011
# Epoch 2977/3000
# 6/6 - 0s - loss: 0.0012
# Epoch 2978/3000
# 6/6 - 0s - loss: 0.0017
# Epoch 2979/3000
# 6/6 - 0s - loss: 0.0012
# Epoch 2980/3000
# 6/6 - 0s - loss: 0.0017
# Epoch 2981/3000
# 6/6 - 0s - loss: 0.0014
# Epoch 2982/3000
# 6/6 - 0s - loss: 0.0020
# Epoch 2983/3000
# 6/6 - 0s - loss: 0.0023
# Epoch 2984/3000
# 6/6 - 0s - loss: 0.0017
# Epoch 2985/3000
# 6/6 - 0s - loss: 0.0027
# Epoch 2986/3000
# 6/6 - 0s - loss: 0.0017
# Epoch 2987/3000
# 6/6 - 0s - loss: 0.0036
# Epoch 2988/3000
# 6/6 - 0s - loss: 0.0023
# Epoch 2989/3000
# 6/6 - 0s - loss: 0.0032
# Epoch 2990/3000
# 6/6 - 0s - loss: 0.0022
# Epoch 2991/3000
# 6/6 - 0s - loss: 0.0033
# Epoch 2992/3000
# 6/6 - 0s - loss: 0.0031
# Epoch 2993/3000
# 6/6 - 0s - loss: 0.0029
# Epoch 2994/3000
# 6/6 - 0s - loss: 0.0028
# Epoch 2995/3000
# 6/6 - 0s - loss: 0.0026
# Epoch 2996/3000
# 6/6 - 0s - loss: 0.0032
# Epoch 2997/3000
# 6/6 - 0s - loss: 0.0022
# Epoch 2998/3000
# 6/6 - 0s - loss: 0.0023
# Epoch 2999/3000
# 6/6 - 0s - loss: 0.0020
# Epoch 3000/3000
# 6/6 - 0s - loss: 0.0022

# %%
X_scaled = X_scaler.transform(X)
predictions = model.predict(X_scaled)
print(f"True output:{y[0]}")
print(f"Predicted output:{y_scaler.inverse_transform(predictions[0]).round(2)}") 
print(f"Prediction Error:{y_scaler.inverse_transform(predictions[0]).round(2)-y[0]}")
# Out:
# True output:[258.]
# Predicted output:[321.79]
# Prediction Error:[63.79000854]

# %%
predicted_y = y_scaler.inverse_transform(predictions).round(2)

# %%
sns.set(style='white')

plt.figure(figsize=(10, 5), dpi=100)
plt.plot(df_Covid_data_Offset.index, predicted_y, label="Predicted", linewidth=1, marker='.', markersize=5, color='blue')
plt.plot(df_Covid_data_Offset.index, df_Covid_data_Offset['onVentilatorCurrently'], label="Actual", linewidth=1, marker='.', markersize=5, color='red')
# plt.plot(dc.index, dc["Error"], label="Error", linewidth=1, marker='.', markersize=10, color='green')


plt.xticks(df_Covid_data.index[::10], rotation=90)
plt.title('Actual vs Predicted')
plt.xlabel('date')
plt.ylabel('Used Ventilators')

plt.legend()
#plt.savefig('covid_outbreak.png', dpi=100)
plt.show()

# %% [markdown]
# ### Saving the model

# %%
# Save the model
# model.save("BEST_On_Ventilator_ANN_"+today.strftime("%Y-%m-%d")+".h5")

# %%
# Load the model
from tensorflow.keras.models import load_model
model = load_model("BEST_On_Ventilator_ANN_2020-12-10.h5")

# %% [markdown]
# ### Load and prepare the data that we will make the future predictions on

# %%
# Loads the last saved data. Make sure the data is up to date by running the cell above. 
Prediction_data = pd.read_csv('df_Covid_data_Offset_prediction2020-12-10.csv')
Prediction_data = Prediction_data.set_index("date").dropna()
Prediction_data
# Out:
#             hospitalizedIncrease  hospitalizedCurrently  positive  \
# date
# 3/25/2020                   1949                 5140.0     75242
# 3/26/2020                   2478                 7805.0     92976
# 3/27/2020                   2572                10978.0    112220
# 3/28/2020                   2409                12409.0    131826
# 3/29/2020                   2794                14055.0    151270
# ...                          ...                    ...       ...
# 12/11/2020                  5578               111728.0  15576982
# 12/12/2020                  5610               112377.0  15733399
# 12/13/2020                  5572               111615.0  15973253
# 12/14/2020                  5684               113864.0  16164569
# 12/15/2020                  5783               115843.0  16332015
#
#             positiveIncrease  recovered  onVentilatorCurrently  \
# date
# 3/25/2020              12891      146.0                  167.0
# 3/26/2020              17734       97.0                  258.0
# 3/27/2020              19244     2418.0                  324.0
# 3/28/2020              19606     3145.0                  390.0
# 3/29/2020              19444     4076.0                  439.0
# ...                      ...        ...                    ...
# 12/11/2020            227354  6147116.0                    0.0
# 12/12/2020            156417  6192058.0                    0.0
# 12/13/2020            239854  6288834.0                    0.0
# 12/14/2020            191316  6386712.0                    0.0
# 12/15/2020            167445  6438448.0                    0.0
#
#             positive_shifted_1  positive_shifted_3  positive_shifted_7  \
# date
# 3/25/2020              92976.0            131826.0            224040.0
# 3/26/2020             112220.0            151270.0            252085.0
# 3/27/2020             131826.0            172740.0            283923.0
# 3/28/2020             151270.0            197924.0            316808.0
# 3/29/2020             172740.0            224040.0            342463.0
# ...                        ...                 ...                 ...
# 12/11/2020          15733399.0          16164569.0          16976003.0
# 12/12/2020          15973253.0          16332015.0          17236260.0
# 12/13/2020          16164569.0          16514745.0          17514627.0
# 12/14/2020          16332015.0          16733585.0          17778197.0
# 12/15/2020          16514745.0          16976003.0          17998336.0
#
#             positive_shifted_10  hospitalizedCurrently_shifted_1  \
# date
# 3/25/2020              316808.0                           7805.0
# 3/26/2020              342463.0                          10978.0
# 3/27/2020              370872.0                          12409.0
# 3/28/2020              401573.0                          14055.0
# 3/29/2020              432490.0                          15917.0
# ...                         ...                              ...
# 12/11/2020           17778197.0                         112377.0
# 12/12/2020           17998336.0                         111615.0
# 12/13/2020           18221436.0                         113864.0
# 12/14/2020           18487325.0                         115843.0
# 12/15/2020           18748601.0                         119308.0
#
#             hospitalizedCurrently_shifted_3  hospitalizedCurrently_shifted_7  \
# date
# 3/25/2020                           12409.0                          20906.0
# 3/26/2020                           14055.0                          22997.0
# 3/27/2020                           15917.0                          25777.0
# 3/28/2020                           18155.0                          30268.0
# 3/29/2020                           20906.0                          32180.0
# ...                                     ...                              ...
# 12/11/2020                         113864.0                         124486.0
# 12/12/2020                         115843.0                         125023.0
# 12/13/2020                         119308.0                         125669.0
# 12/14/2020                         122569.0                         128201.0
# 12/15/2020                         124486.0                         130429.0
#
#             hospitalizedCurrently_shifted_10  recovered_shifted_1  \
# date
# 3/25/2020                            30268.0                 97.0
# 3/26/2020                            32180.0               2418.0
# 3/27/2020                            36159.0               3145.0
# 3/28/2020                            43849.0               4076.0
# 3/29/2020                            45515.0               4560.0
# ...                                      ...                  ...
# 12/11/2020                          128201.0            6192058.0
# 12/12/2020                          130429.0            6288834.0
# 12/13/2020                          134330.0            6386712.0
# 12/14/2020                          137541.0            6438448.0
# 12/15/2020                          140300.0            6542039.0
#
#             recovered_shifted_3  recovered_shifted_7  recovered_shifted_10
# date
# 3/25/2020                3145.0               7084.0               12844.0
# 3/26/2020                4076.0               8586.0               14589.0
# 3/27/2020                4560.0              10861.0               16557.0
# 3/28/2020                5666.0              12844.0               18481.0
# 3/29/2020                7084.0              14589.0               21132.0
# ...                         ...                  ...                   ...
# 12/11/2020            6386712.0            6765103.0             7088000.0
# 12/12/2020            6438448.0            6869195.0             7149595.0
# 12/13/2020            6542039.0            6953561.0             7263930.0
# 12/14/2020            6643650.0            7088000.0             7357932.0
# 12/15/2020            6765103.0            7149595.0             7486808.0
#
# [266 rows x 18 columns]

# %%
X_predict = Prediction_data[['hospitalizedIncrease','hospitalizedCurrently','positive',\
             'positiveIncrease','recovered',"positive_shifted_1", "positive_shifted_3","positive_shifted_7","positive_shifted_10",\
                  "hospitalizedCurrently_shifted_1","hospitalizedCurrently_shifted_3","hospitalizedCurrently_shifted_7","hospitalizedCurrently_shifted_10",\
                  "recovered_shifted_1", "recovered_shifted_3","recovered_shifted_7","recovered_shifted_10"]]
y_predict = Prediction_data['onVentilatorCurrently'].values.reshape(-1,1)

# %%
X_predict_scaled = X_scaler.transform(X_predict)
predictions = model.predict(X_predict_scaled)
print(f"True output:{y_predict[0]}")
print(f"Predicted output:{y_scaler.inverse_transform(predictions[0]).round(0)}") 
print(f"Prediction Error:{y_scaler.inverse_transform(predictions[0]).round(0)-y_predict[0]}")
# Out:
# True output:[167.]
# Predicted output:[513.]
# Prediction Error:[346.]

# %%
X_predict_scaled
# Out:
# array([[-0.09436981, -2.50916542, -1.33517969, ..., -1.18660325,
#         -1.1934165 , -1.19740924],
#        [ 0.22987502, -2.33909538, -1.33004929, ..., -1.1859697 ,
#         -1.19243627, -1.19630538],
#        [ 0.2874913 , -2.13660674, -1.32448205, ..., -1.18564034,
#         -1.19095156, -1.19506046],
#        ...,
#        [ 2.12630884,  4.28565899,  3.26407444, ...,  3.26310027,
#          3.33999278,  3.38948486],
#        [ 2.19495803,  4.42918151,  3.31942168, ...,  3.33224634,
#          3.42773035,  3.44894867],
#        [ 2.25563901,  4.55547367,  3.36786338, ...,  3.41489485,
#          3.46792848,  3.53047309]])

# %%
predicted_y = y_scaler.inverse_transform(predictions).round(0)
predicted_y
# Out:
# array([[ 513.],
#        [ 342.],
#        [ 359.],
#        [ 420.],
#        [ 493.],
#        [ 541.],
#        [ 511.],
#        [ 525.],
#        [ 553.],
#        [ 578.],
#        [ 562.],
#        [ 864.],
#        [2848.],
#        [3983.],
#        [4147.],
#        [5554.],
#        [5720.],
#        [5778.],
#        [5874.],
#        [5959.],
#        [5686.],
#        [5756.],
#        [5703.],
#        [5914.],
#        [5895.],
#        [5531.],
#        [5276.],
#        [5202.],
#        [5516.],
#        [5323.],
#        [5017.],
#        [5143.],
#        [5014.],
#        [4789.],
#        [4235.],
#        [5500.],
#        [4642.],
#        [6451.],
#        [4551.],
#        [4569.],
#        [4400.],
#        [4152.],
#        [4431.],
#        [6770.],
#        [6541.],
#        [5933.],
#        [6032.],
#        [6017.],
#        [5812.],
#        [5972.],
#        [6072.],
#        [5779.],
#        [5738.],
#        [5396.],
#        [5219.],
#        [5089.],
#        [4920.],
#        [4915.],
#        [4682.],
#        [4470.],
#        [4387.],
#        [4254.],
#        [4381.],
#        [4135.],
#        [4084.],
#        [3987.],
#        [3885.],
#        [3771.],
#        [3886.],
#        [3758.],
#        [3741.],
#        [3764.],
#        [3601.],
#        [3469.],
#        [3303.],
#        [3197.],
#        [3127.],
#        [3047.],
#        [2913.],
#        [2791.],
#        [2764.],
#        [2715.],
#        [2646.],
#        [2584.],
#        [2531.],
#        [2508.],
#        [2437.],
#        [2420.],
#        [2401.],
#        [2299.],
#        [2271.],
#        [2322.],
#        [2229.],
#        [1980.],
#        [2097.],
#        [2165.],
#        [2116.],
#        [1951.],
#        [2012.],
#        [2039.],
#        [2027.],
#        [2019.],
#        [2050.],
#        [2072.],
#        [1957.],
#        [1984.],
#        [2038.],
#        [2154.],
#        [2136.],
#        [2153.],
#        [2176.],
#        [2209.],
#        [2237.],
#        [2266.],
#        [2282.],
#        [2314.],
#        [2323.],
#        [2372.],
#        [2426.],
#        [2459.],
#        [2499.],
#        [2532.],
#        [2574.],
#        [2562.],
#        [2606.],
#        [2660.],
#        [2669.],
#        [2668.],
#        [2667.],
#        [2667.],
#        [2564.],
#        [2630.],
#        [2623.],
#        [2644.],
#        [2639.],
#        [2669.],
#        [2537.],
#        [2483.],
#        [2493.],
#        [2535.],
#        [2524.],
#        [2491.],
#        [2442.],
#        [2416.],
#        [2349.],
#        [2356.],
#        [2384.],
#        [2352.],
#        [2293.],
#        [2252.],
#        [2207.],
#        [2139.],
#        [2124.],
#        [2159.],
#        [2110.],
#        [2079.],
#        [2048.],
#        [2006.],
#        [1955.],
#        [1962.],
#        [1993.],
#        [1989.],
#        [1928.],
#        [1868.],
#        [1855.],
#        [1799.],
#        [1792.],
#        [1818.],
#        [1842.],
#        [1796.],
#        [1734.],
#        [1644.],
#        [1587.],
#        [1589.],
#        [1600.],
#        [1583.],
#        [1568.],
#        [1549.],
#        [1522.],
#        [1484.],
#        [1499.],
#        [1524.],
#        [1513.],
#        [1508.],
#        [1504.],
#        [1485.],
#        [1457.],
#        [1469.],
#        [1485.],
#        [1491.],
#        [1485.],
#        [1494.],
#        [1485.],
#        [1480.],
#        [1512.],
#        [1549.],
#        [1606.],
#        [1637.],
#        [1650.],
#        [1647.],
#        [1625.],
#        [1651.],
#        [1703.],
#        [1746.],
#        [1787.],
#        [1820.],
#        [1816.],
#        [1830.],
#        [1900.],
#        [1972.],
#        [2064.],
#        [2104.],
#        [2128.],
#        [2164.],
#        [2193.],
#        [2252.],
#        [2310.],
#        [2360.],
#        [2415.],
#        [2457.],
#        [2471.],
#        [2516.],
#        [2596.],
#        [2710.],
#        [2759.],
#        [2812.],
#        [2837.],
#        [2865.],
#        [2943.],
#        [3075.],
#        [3164.],
#        [3348.],
#        [3583.],
#        [3783.],
#        [3862.],
#        [3916.],
#        [4131.],
#        [4443.],
#        [4652.],
#        [4792.],
#        [4954.],
#        [5032.],
#        [5070.],
#        [5311.],
#        [5566.],
#        [5833.],
#        [5884.],
#        [5937.],
#        [6042.],
#        [6162.],
#        [6449.],
#        [6740.],
#        [6959.],
#        [7089.],
#        [7199.],
#        [7206.],
#        [7146.],
#        [7249.],
#        [7555.],
#        [7794.],
#        [8097.],
#        [8385.],
#        [8323.],
#        [8418.],
#        [8555.],
#        [8717.]], dtype=float32)

# %%
sns.set(style='white')

plt.figure(figsize=(10, 5), dpi=100)
plt.plot(Prediction_data.index, predicted_y, label="Predicted", linewidth=1, marker='.', markersize=5, color='blue')
plt.plot(Prediction_data.index, Prediction_data['onVentilatorCurrently'], label="Actual", linewidth=1, marker='.', markersize=5, color='red')
# plt.plot(dc.index, dc["Error"], label="Error", linewidth=1, marker='.', markersize=10, color='green')


plt.xticks(Prediction_data.index[::5], rotation=90)
plt.title('Actual vs Predicted')
plt.xlabel('date')
plt.ylabel('Used Ventilators')

plt.legend()
#plt.savefig('covid_outbreak.png', dpi=100)
plt.show()

# %%
# def prediction_plot(testY, test_predict):
#       len_prediction=[x for x in range(len(testY))]
#       plt.figure(figsize=(8,4))
#       plt.plot(len_prediction, testY[:l], marker='.', label="actual")
#       plt.plot(len_prediction, test_predict[:l], 'r', label="prediction")
#       plt.tight_layout()
#       sns.despine(top=True)
#       plt.subplots_adjust(left=0.07)
#       plt.ylabel('Ads Daily Spend', size=15)
#       plt.xlabel('Time step', size=15)
#       plt.legend(fontsize=15)
#       plt.show();

# %%
pip install plotly==4.14.1
# Out:
# Collecting plotly==4.14.1
#   Downloading plotly-4.14.1-py2.py3-none-any.whl (13.2 MB)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: six in c:\users\stoja\anaconda3\envs\pythonadv\lib\site-packages (from plotly==4.14.1) (1.15.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=
                                   dash='solid')))

fig5.update_layout(title={'text': '<b>Ventilators Used/Prediction</b>',
                         'y': 0.9,
                         'x': 0.5,
                         'xanchor': 'center',
                         'yanchor': 'top'
                         },
                  font=dict(size=16, color="black")
                  )

annotations = []

fig5.update_xaxes(title_text="Date",
                 tickfont=dict(size=12),
                 titlefont=dict(size=16))

fig5.update_yaxes(title_text="On Ventilator",
                 tickfont=dict(size=12),
                 titlefont=dict(size=16))

fig5.update_layout(template='plotly_white')

fig5.update_layout(xaxis=dict(tickformat="%m-%d"))
fig5.update_xaxes(range=['2020-04-30', df_Covid_data_Offset.index.values[-1]])

fig5.update_layout(annotations=annotations)

fig5.update_layout(hovermode="x")
fig5.update_layout(showlegend=False)

fig5.update_layout(
    autosize=True,
    height=600,
    margin=dict(l=0, r=0)
)

fig5.add_shape(
    dict(
        type="line",
        x0=250,
        y0=0,
        x1=250,
        y1=9000,
        line=dict(
            color='rgb(65, 65, 69)',
            width=2
        )
    ))

fig5.show()
# Out:
# <div>                            <div id="c65b1591-9600-4f43-a334-a7948d54c93a" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c65b1591-9600-4f43-a334-a7948d54c93a")) {                    Plotly.newPlot(                        "c65b1591-9600-4f43-a334-a7948d54c93a",                        [{"line": {"color": "rgb(204, 152, 237)", "dash": "dot", "width": 2}, "name": "Prediction", "type": "scatter", "x": ["3/25/2020", "3/26/2020", "3/27/2020", "3/28/2020", "3/29/2020", "3/30/2020", "3/31/2020", "4/1/2020", "4/2/2020", "4/3/2020", "4/4/2020", "4/5/2020", "4/6/2020", "4/7/2020", "4/8/2020", "4/9/2020", "4/10/2020", "4/11/2020", "4/12/2020", "4/13/2020", "4/14/2020", "4/15/2020", "4/16/2020", "4/17/2020", "4/18/2020", "4/19/2020", "4/20/2020", "4/21/2020", "4/22/2020", "4/23/2020", "4/24/2020", "4/25/2020", "4/26/2020", "4/27/2020", "4/28/2020", "4/29/2020", "4/30/2020", "5/1/2020", "5/2/2020", "5/3/2020", "5/4/2020", "5/5/2020", "5/6/2020", "5/7/2020", "5/8/2020", "5/9/2020", "5/10/2020", "5/11/2020", "5/12/2020", "5/13/2020", "5/14/2020", "5/15/2020", "5/16/2020", "5/17/2020", "5/18/2020", "5/19/2020", "5/20/2020", "5/21/2020", "5/22/2020", "5/23/2020", "5/24/2020", "5/25/2020", "5/26/2020", "5/27/2020", "5/28/2020", "5/29/2020", "5/30/2020", "5/31/2020", "6/1/2020", "6/2/2020", "6/3/2020", "6/4/2020", "6/5/2020", "6/6/2020", "6/7/2020", "6/8/2020", "6/9/2020", "6/10/2020", "6/11/2020", "6/12/2020", "6/13/2020", "6/14/2020", "6/15/2020", "6/16/2020", "6/17/2020", "6/18/2020", "6/19/2020", "6/20/2020", "6/21/2020", "6/22/2020", "6/23/2020", "6/24/2020", "6/25/2020", "6/26/2020", "6/27/2020", "6/28/2020", "6/29/2020", "6/30/2020", "7/1/2020", "7/2/2020", "7/3/2020", "7/4/2020", "7/5/2020", "7/6/2020", "7/7/2020", "7/8/2020", "7/9/2020", "7/10/2020", "7/11/2020", "7/12/2020", "7/13